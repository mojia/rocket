# %%
# %run Util.ipynb
# %run OperationRegression.ipynb

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.tools.plotting import scatter_matrix

# %matplotlib inline
mpl.style.use('ggplot')
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
sns.set_style('white')

regression = OperationRegression(4,'2000-01-01','2019-01-01', short=30, mid=60)
regression.run()

operations = regression.get_operations()
operations
# Out:
# SZ#000050 No Week K
# SZ#000050 file:/Users/xinwang/stock/data/day/D_SZ#000050.txt
# start to analyse Week level SZ#000050 all cross sections...

# %%
part_report = regression.report()
part_report

# %%
title='MA(30.60); 7% losss, sell price is that day stop loss price; one stock; risk asset is 3%;\n'
regression.draw_asset(title)
# Out:
# 每年增长幅度为:[-3.0, 294.9, 13.8, 14.3]

# %%
# %run Util.ipynb
# %run OperationRegression.ipynb

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.tools.plotting import scatter_matrix

# %matplotlib inline
mpl.style.use('ggplot')
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
sns.set_style('white')


report_df=pd.DataFrame(columns=system_report_columns)
dates = ['1990-01-01','2000-06-01','2004-09-01','2005-01-01','2007-01-01','2010-01-01',
        '2012-01-01','2014-01-01','2016-01-01']

for date in dates:
    regression = OperationRegression(400, date, '2019-01-01', short=30, mid=60)
    regression.run()

    part_report = regression.report()
    report_df = pd.concat([part_report,report_df], ignore_index=True, sort=False)
    
    title='MA(30.60); 7% losss, sell price is that day close price; one stock; risk asset is 3%;\n'
    regression.draw_asset(title)
    
    
print('report_df\n'+str(report_df))
report_df.describe()
# Out:
# find all cross sections...
#
# start to run operation regression [1990-01-01,2019-01-01]
# 每年增长幅度为:[15.2, 8.3, -3.0, 294.9, -0.4, 32.1, -3.0, 14.3]
# find all cross sections...
#
# start to run operation regression [2000-06-01,2019-01-01]
# 每年增长幅度为:[15.2, 8.3, -3.0, 294.9, -0.4, 32.1, -3.0, 14.3]
# find all cross sections...
#
# start to run operation regression [2004-09-01,2019-01-01]
# 每年增长幅度为:[-3.0, -3.0, 295.1, -0.4, 32.0, -3.0, 14.3]
# find all cross sections...
#
# start to run operation regression [2005-01-01,2019-01-01]
# 每年增长幅度为:[-3.0, 294.9, -0.4, 32.0, -3.0, 14.3]
# find all cross sections...
#
# start to run operation regression [2007-01-01,2019-01-01]
# 每年增长幅度为:[-0.4, 31.8, -3.0, 14.1]
# find all cross sections...
#
# start to run operation regression [2010-01-01,2019-01-01]
# 每年增长幅度为:[-0.4, 31.8, -3.0, 14.1]
# find all cross sections...
#
# start to run operation regression [2012-01-01,2019-01-01]
# 每年增长幅度为:[-0.4, 31.8, -3.0, 14.1]
# find all cross sections...
#
# start to run operation regression [2014-01-01,2019-01-01]
# 每年增长幅度为:[-0.4, 31.8, -3.0, 14.1]
# find all cross sections...
#
# start to run operation regression [2016-01-01,2019-01-01]
# 每年增长幅度为:[-2.9, 14.2]
# report_df
#    total_profit   win_rate  loss_times  retrace  deal_count  win_count  \
# 0      10.88492  50.000000         1.0    12.58         2.0        1.0
# 1      45.33652  40.000000         2.0    31.99         5.0        2.0
# 2      45.33652  40.000000         2.0    31.99         5.0        2.0
# 3      45.33652  40.000000         2.0    31.99         5.0        2.0
# 4      45.33652  40.000000         2.0    31.99         5.0        2.0
# 5     458.51984  42.857143         2.0    32.02         7.0        3.0
# 6     442.06298  37.500000         2.0    32.06         8.0        3.0
# 7     597.19102  50.000000         2.0    32.05        10.0        5.0
# 8     597.19102  50.000000         2.0    32.05        10.0        5.0
#
#    period_profit_score  year_return_rate
# 0                 50.0             40.68
# 1                 50.0             33.03
# 2                 50.0             22.70
# 3                 50.0             17.30
# 4                 50.0             12.74
# 5                 50.0             43.27
# 6                 42.9             41.07
# 7                 50.0             40.83
# 8                 50.0             25.35
#        total_profit   win_rate  loss_times    retrace  deal_count  win_count  \
# count      9.000000   9.000000    9.000000   9.000000    9.000000   9.000000
# mean     254.132873  43.373016    1.888889  29.857778    6.333333   2.777778
# std      261.252459   5.148035    0.333333   6.479234    2.645751   1.394433
# min       10.884920  37.500000    1.000000  12.580000    2.000000   1.000000
# 25%       45.336520  40.000000    2.000000  31.990000    5.000000   2.000000
# 50%       45.336520  40.000000    2.000000  31.990000    5.000000   2.000000
# 75%      458.519840  50.000000    2.000000  32.050000    8.000000   3.000000
# max      597.191020  50.000000    2.000000  32.060000   10.000000   5.000000
#
#        period_profit_score  year_return_rate
# count             9.000000          9.000000
# mean             49.211111         30.774444
# std               2.366667         11.553583
# min              42.900000         12.740000
# 25%              50.000000         22.700000
# 50%              50.000000         33.030000
# 75%              50.000000         40.830000
# max              50.000000         43.270000
