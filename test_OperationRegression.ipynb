# %%
# %run Util.ipynb
# %run OperationRegression.ipynb

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.tools.plotting import scatter_matrix

# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')

symbols = get_symbols(scale=2)
regression = OperationRegression(symbols, '2000-01-01','2019-01-01', short=30, mid=60)
regression.run()

operations = regression.get_operations()
operations
# Out:
# find all cross sections...
# start to run operation regression...
# 2003-01-24 开仓 SZ#000652 21400 shares
# 2003-08-20 清仓 SZ#000652 21400 shares
# 2003-12-15 开仓 SZ#000960 15800 shares
# 2004-06-02 清仓 SZ#000960 15800 shares
# 2004-07-07 开仓 SZ#000960 14200 shares
# 2004-09-09 清仓 SZ#000960 14200 shares
# 2004-10-25 开仓 SZ#000960 11800 shares
# 2004-12-20 清仓 SZ#000960 11800 shares
# 2005-03-04 开仓 SZ#000960 11900 shares
# 2005-03-22 清仓 SZ#000960 11900 shares
# 2006-04-14 开仓 SZ#000001 49200 shares
# 2006-04-24 清仓 SZ#000001 49200 shares
# 2006-09-21 开仓 SZ#000001 38700 shares
# 2007-12-12 清仓 SZ#000001 38700 shares
# 2008-01-11 开仓 SZ#000652 9700 shares
# 2008-01-18 清仓 SZ#000652 9700 shares
# 2008-01-31 开仓 SZ#000960 5600 shares
# 2008-02-18 清仓 SZ#000960 5600 shares
# 2008-06-05 开仓 SZ#000960 8000 shares
# 2008-06-10 清仓 SZ#000960 8000 shares
# 2009-11-04 开仓 SZ#000001 20900 shares
# 2009-11-26 清仓 SZ#000001 20900 shares
# 2010-03-17 开仓 SZ#000652 21200 shares
# 2010-06-07 清仓 SZ#000652 21200 shares
# 2010-08-25 开仓 SZ#000652 22000 shares
# 2011-07-20 清仓 SZ#000652 22000 shares
# 2011-12-02 开仓 SZ#000001 32900 shares
# 2011-12-08 清仓 SZ#000001 32900 shares
# 2013-06-19 开仓 SZ#000001 26400 shares
# 2013-06-21 清仓 SZ#000001 26400 shares
# 2013-09-02 开仓 SZ#000652 43500 shares
# 2014-01-22 清仓 SZ#000652 43500 shares
# 2014-02-27 开仓 SZ#000652 39800 shares
# 2014-04-04 清仓 SZ#000652 39800 shares
# 2014-05-12 开仓 SZ#000001 28500 shares
# 2014-10-09 清仓 SZ#000001 28500 shares
# 2014-11-11 开仓 SZ#000001 24200 shares
# 2015-02-26 清仓 SZ#000001 24200 shares
# 2015-03-05 开仓 SZ#000652 25900 shares
# 2015-07-06 清仓 SZ#000652 25900 shares
# 2015-11-11 开仓 SZ#000001 18700 shares
# 2016-01-04 清仓 SZ#000001 18700 shares
# 2016-10-21 开仓 SZ#000960 12500 shares
# 2016-12-23 清仓 SZ#000960 12500 shares
# 2017-02-27 开仓 SZ#000001 18900 shares
# 2017-04-11 清仓 SZ#000001 18900 shares
# 2017-06-23 开仓 SZ#000001 19100 shares
# 2018-03-06 清仓 SZ#000001 19100 shares
# 2018-05-28 开仓 SZ#000960 13000 shares
# 2018-06-12 清仓 SZ#000960 13000 shares
#        symbol    buy_date   sell_date  buy_price  sell_price shares space  \
# 24  SZ#000652  2003-01-24  2003-08-20       2.00        2.71  21400     0
# 23  SZ#000960  2003-12-15  2004-06-02       3.12        3.97  15800     0
# 22  SZ#000960  2004-07-07  2004-09-09       3.88        3.58  14200     0
# 21  SZ#000960  2004-10-25  2004-12-20       4.51        4.06  11800     0
# 20  SZ#000960  2005-03-04  2005-03-22       4.28        3.84  11900     0
# 19  SZ#000001  2006-04-14  2006-04-24       0.99        0.90  49200     0
# 18  SZ#000001  2006-09-21  2007-12-12       1.21        9.55  38700     0
# 17  SZ#000652  2008-01-11  2008-01-18      19.00       17.54   9700     0
# 16  SZ#000960  2008-01-31  2008-02-18      31.61       32.91   5600     0
# 15  SZ#000960  2008-06-05  2008-06-10      22.71       21.09   8000     0
# 14  SZ#000001  2009-11-04  2009-11-26       8.45        7.85  20900     0
# 13  SZ#000652  2010-03-17  2010-06-07       8.07        7.66  21200     0
# 12  SZ#000652  2010-08-25  2011-07-20       7.60        7.42  22000     0
# 11  SZ#000001  2011-12-02  2011-12-08       5.04        5.03  32900     0
# 10  SZ#000001  2013-06-19  2013-06-21       6.26        5.89  26400     0
# 9   SZ#000652  2013-09-02  2014-01-22       3.71        4.16  43500     0
# 8   SZ#000652  2014-02-27  2014-04-04       4.27        4.23  39800     0
# 7   SZ#000001  2014-05-12  2014-10-09       5.93        6.54  28500     0
# 6   SZ#000001  2014-11-11  2015-02-26       7.28        9.23  24200     0
# 5   SZ#000652  2015-03-05  2015-07-06       7.60        6.79  25900     0
# 4   SZ#000001  2015-11-11  2016-01-04      10.04        9.02  18700     0
# 3   SZ#000960  2016-10-21  2016-12-23      14.36       13.19  12500     0
# 2   SZ#000001  2017-02-27  2017-04-11       9.14        8.86  18900     0
# 1   SZ#000001  2017-06-23  2018-03-06       8.96       11.96  19100     0
# 0   SZ#000960  2018-05-28  2018-06-12      14.98       13.75  13000     0
#
#     profit_rate      cash
# 24    35.500000  115194.0
# 23    27.243590  128624.0
# 22    -7.731959  124364.0
# 21    -9.977827  119054.0
# 20   -10.280374  113818.0
# 19    -9.090909  109390.0
# 18   689.256198  432148.0
# 17    -7.684211  417986.0
# 16     4.112623  425266.0
# 15    -7.133421  412306.0
# 14    -7.100592  399766.0
# 13    -5.080545  391074.0
# 12    -2.368421  387114.0
# 11    -0.198413  386785.0
# 10    -5.910543  377017.0
# 9     12.129380  396592.0
# 8     -0.936768  395000.0
# 7     10.286678  412385.0
# 6     26.785714  459575.0
# 5    -10.657895  438596.0
# 4    -10.159363  419522.0
# 3     -8.147632  404897.0
# 2     -3.063457  399605.0
# 1     33.482143  456905.0
# 0     -8.210948  440915.0

# %%
part_report = regression.report()
part_report
# Out:
# 每年增长幅度为:[15.2, 3.4, -4.4, -3.9, 295.1, -4.6, -3.0, -2.2, -1.1, -2.5, 9.4, 6.4, -7.7, -1.3, 10.3]
#    total_profit  win_rate  loss_times  retrace  deal_count  win_count  \
# 1       340.915      32.0         6.0    37.12        25.0        8.0
#
#    period_profit_score
# 1                 20.0

# %%
title='MA(30.60); 7% losss, sell price is that day close price; one stock; risk asset is 3%;\n'
regression.draw_asset(title)
# Out:
# 每年增长幅度为:[15.2, 3.4, -4.4, -3.9, 295.1, -4.6, -3.0, -2.2, -1.1, -2.5, 9.4, 6.4, -7.7, -1.3, 10.3]

# %%
symbols = get_symbols(scale=3)
print('symbols ' + str(len(symbols)))


report_df=pd.DataFrame(columns=system_report_columns)
dates = ['1990-01-01','2000-06-01','2004-09-01','2005-01-01','2007-01-01','2010-01-01',
        '2012-01-01','2014-01-01']
for i in range(0,3):
    regression = OperationRegression(symbols, '1990-01-01','2019-01-01', short=30, mid=60)
    regression.run()

    part_report = regression.report()
    report_df = pd.concat([part_report,report_df], ignore_index=True, sort=False)
    
    title='MA(30.60); 7% losss, sell price is that day close price; one stock; risk asset is 3%;\n'
    regression.draw_asset(title)
# Out:
# symbols 400
# find all cross sections...
# 1.25% 2.5% 3.75% 5.0% 6.25% 7.5% 8.75% 10.0% 11.25% 12.5% 13.75% 15.0% 16.25% 17.5% 18.75% 20.0% 21.25% 22.5% 23.75% 25.0% 26.25% 27.5% 28.75% 30.0% 31.25% 32.5% 33.75% 35.0% 36.25% 37.5% 38.75% 40.0%
