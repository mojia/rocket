# %%
# %run BasicDataRebuilder.ipynb


rebuild = BasicDataRebuilder()
rebuild.rebuild_all_sections(100,200,30,60)
# Out:
# rebuild_all_sections get 100 symbols
# load SZ#000012 sections from file
# load SZ#000667 sections from file
# 2.0 load SZ#000971 sections from file
# load SZ#002187 sections from file
# 4.0 load SZ#002401 sections from file
# load SZ#002615 sections from file
# 6.0 load SZ#002839 sections from file
# load SZ#300119 sections from file
# 8.0 load SZ#300333 sections from file
# load SZ#300550 sections from file
# 10.0 load SZ#000014 sections from file
# load SZ#000668 sections from file
# 12.0 load SZ#000972 sections from file
# load SZ#002188 sections from file
# 14.0 load SZ#002402 sections from file
# load SZ#002616 sections from file
# 16.0 load SZ#002840 sections from file
# load SZ#300120 sections from file
# 18.0 load SZ#300334 sections from file
# load SZ#300551 sections from file
# 20.0 build SZ#000016 sections
# start to analyse Day level SZ#000016 all cross sections...
# build SZ#000669 sections
# start to analyse Day level SZ#000669 all cross sections...
# 22.0 build SZ#000973 sections
# start to analyse Day level SZ#000973 all cross sections...
# build SZ#002189 sections
# start to analyse Day level SZ#002189 all cross sections...
# 24.0 build SZ#002403 sections
# start to analyse Day level SZ#002403 all cross sections...
# build SZ#002617 sections
# start to analyse Day level SZ#002617 all cross sections...
# 26.0 build SZ#002841 sections
# start to analyse Day level SZ#002841 all cross sections...
# build SZ#300121 sections
# start to analyse Day level SZ#300121 all cross sections...
# 28.0 build SZ#300335 sections
# start to analyse Day level SZ#300335 all cross sections...
# build SZ#300552 sections
# start to analyse Day level SZ#300552 all cross sections...
# 30.0 build SZ#000017 sections
# start to analyse Day level SZ#000017 all cross sections...
# build SZ#000670 sections
# start to analyse Day level SZ#000670 all cross sections...
# 32.0 build SZ#000975 sections
# start to analyse Day level SZ#000975 all cross sections...
# build SZ#002190 sections
# start to analyse Day level SZ#002190 all cross sections...
# 34.0 build SZ#002404 sections
# start to analyse Day level SZ#002404 all cross sections...
# build SZ#002618 sections
# start to analyse Day level SZ#002618 all cross sections...
# 36.0 build SZ#002842 sections
# start to analyse Day level SZ#002842 all cross sections...
# build SZ#300122 sections
# start to analyse Day level SZ#300122 all cross sections...
# 38.0 build SZ#300336 sections
# start to analyse Day level SZ#300336 all cross sections...
# build SZ#300553 sections
# start to analyse Day level SZ#300553 all cross sections...
# 40.0 build SZ#000018 sections
# start to analyse Day level SZ#000018 all cross sections...
# build SZ#000671 sections
# start to analyse Day level SZ#000671 all cross sections...
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:44: RuntimeWarning: divide by zero encountered in double_scalars
# 42.0 build SZ#000976 sections
# start to analyse Day level SZ#000976 all cross sections...
# build SZ#002191 sections
# start to analyse Day level SZ#002191 all cross sections...
# 44.0 build SZ#002405 sections
# start to analyse Day level SZ#002405 all cross sections...
# build SZ#002619 sections
# start to analyse Day level SZ#002619 all cross sections...
# 46.0 build SZ#002843 sections
# start to analyse Day level SZ#002843 all cross sections...
# build SZ#300123 sections
# start to analyse Day level SZ#300123 all cross sections...
# 48.0 build SZ#300337 sections
# start to analyse Day level SZ#300337 all cross sections...
# build SZ#300554 sections
# start to analyse Day level SZ#300554 all cross sections...
# 50.0 build SZ#000019 sections
# start to analyse Day level SZ#000019 all cross sections...
# build SZ#000672 sections
# start to analyse Day level SZ#000672 all cross sections...
# 52.0 build SZ#000977 sections
# start to analyse Day level SZ#000977 all cross sections...
# build SZ#002192 sections
# start to analyse Day level SZ#002192 all cross sections...
# 54.0 build SZ#002406 sections
# start to analyse Day level SZ#002406 all cross sections...
# build SZ#002620 sections
# start to analyse Day level SZ#002620 all cross sections...
# 56.0 build SZ#002845 sections
# start to analyse Day level SZ#002845 all cross sections...
# build SZ#300124 sections
# start to analyse Day level SZ#300124 all cross sections...
# 58.0 build SZ#300338 sections
# start to analyse Day level SZ#300338 all cross sections...
# build SZ#300555 sections
# start to analyse Day level SZ#300555 all cross sections...
# 60.0 build SZ#000020 sections
# start to analyse Day level SZ#000020 all cross sections...
# build SZ#000673 sections
# start to analyse Day level SZ#000673 all cross sections...
# 62.0 build SZ#000978 sections
# start to analyse Day level SZ#000978 all cross sections...
# build SZ#002193 sections
# start to analyse Day level SZ#002193 all cross sections...
# 64.0 build SZ#002407 sections
# start to analyse Day level SZ#002407 all cross sections...
# build SZ#002621 sections
# start to analyse Day level SZ#002621 all cross sections...
# 66.0 build SZ#002846 sections
# start to analyse Day level SZ#002846 all cross sections...
# build SZ#300125 sections
# start to analyse Day level SZ#300125 all cross sections...
# 68.0 build SZ#300339 sections
# start to analyse Day level SZ#300339 all cross sections...
# build SZ#300556 sections
# start to analyse Day level SZ#300556 all cross sections...
# 70.0 build SZ#000021 sections
# start to analyse Day level SZ#000021 all cross sections...
# build SZ#000676 sections
# start to analyse Day level SZ#000676 all cross sections...
# 72.0 build SZ#000980 sections
# start to analyse Day level SZ#000980 all cross sections...
# build SZ#002194 sections
# start to analyse Day level SZ#002194 all cross sections...
# 74.0 build SZ#002408 sections
# start to analyse Day level SZ#002408 all cross sections...
# build SZ#002622 sections
# start to analyse Day level SZ#002622 all cross sections...
# 76.0 build SZ#002847 sections
# start to analyse Day level SZ#002847 all cross sections...
# build SZ#300126 sections
# start to analyse Day level SZ#300126 all cross sections...
# 78.0 build SZ#300340 sections
# start to analyse Day level SZ#300340 all cross sections...
# build SZ#300557 sections
# start to analyse Day level SZ#300557 all cross sections...
# 80.0 build SZ#000023 sections
# start to analyse Day level SZ#000023 all cross sections...
# build SZ#000677 sections
# start to analyse Day level SZ#000677 all cross sections...
# 82.0 build SZ#000981 sections
# start to analyse Day level SZ#000981 all cross sections...
# build SZ#002195 sections
# start to analyse Day level SZ#002195 all cross sections...
# 84.0 build SZ#002409 sections
# start to analyse Day level SZ#002409 all cross sections...
# build SZ#002623 sections
# start to analyse Day level SZ#002623 all cross sections...
# 86.0 build SZ#002848 sections
# start to analyse Day level SZ#002848 all cross sections...
# build SZ#300127 sections
# start to analyse Day level SZ#300127 all cross sections...
# 88.0 build SZ#300341 sections
# start to analyse Day level SZ#300341 all cross sections...
# build SZ#300558 sections
# start to analyse Day level SZ#300558 all cross sections...
# 90.0 build SZ#000025 sections
# start to analyse Day level SZ#000025 all cross sections...
# build SZ#000678 sections
# start to analyse Day level SZ#000678 all cross sections...
# 92.0 build SZ#000982 sections
# start to analyse Day level SZ#000982 all cross sections...
# build SZ#002196 sections
# start to analyse Day level SZ#002196 all cross sections...
# 94.0 build SZ#002410 sections
# start to analyse Day level SZ#002410 all cross sections...
# build SZ#002624 sections
# start to analyse Day level SZ#002624 all cross sections...
# 96.0 build SZ#002849 sections
# start to analyse Day level SZ#002849 all cross sections...
# build SZ#300128 sections
# start to analyse Day level SZ#300128 all cross sections...
# 98.0 build SZ#300342 sections
# start to analyse Day level SZ#300342 all cross sections...
# build SZ#300559 sections
# start to analyse Day level SZ#300559 all cross sections...
# 100.0

# %%
# %run BasicDataRebuilder.ipynb


rebuild = BasicDataRebuilder()
rebuild.rebuild_chan_data(90,100,30,60)
# Out:
# rebuild chan data get 10 symbols
# 20.0 40.0 60.0 80.0 100.0
