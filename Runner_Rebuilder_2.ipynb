# %%
# %run BasicDataRebuilder.ipynb


rebuild = BasicDataRebuilder()
rebuild.rebuild_all_sections(200,300,30,60)
# Out:
# rebuild_all_sections get 100 symbols
# build SZ#000026 sections
# start to analyse Day level SZ#000026 all cross sections...
# build SZ#000679 sections
# start to analyse Day level SZ#000679 all cross sections...
# 2.0 build SZ#000983 sections
# start to analyse Day level SZ#000983 all cross sections...
# build SZ#002197 sections
# start to analyse Day level SZ#002197 all cross sections...
# 4.0 build SZ#002411 sections
# start to analyse Day level SZ#002411 all cross sections...
# build SZ#002625 sections
# start to analyse Day level SZ#002625 all cross sections...
# 6.0 build SZ#002850 sections
# start to analyse Day level SZ#002850 all cross sections...
# build SZ#300129 sections
# start to analyse Day level SZ#300129 all cross sections...
# 8.0 build SZ#300343 sections
# start to analyse Day level SZ#300343 all cross sections...
# build SZ#300560 sections
# start to analyse Day level SZ#300560 all cross sections...
# 10.0 build SZ#000027 sections
# start to analyse Day level SZ#000027 all cross sections...
# build SZ#000680 sections
# start to analyse Day level SZ#000680 all cross sections...
# 12.0 build SZ#000985 sections
# start to analyse Day level SZ#000985 all cross sections...
# build SZ#002198 sections
# start to analyse Day level SZ#002198 all cross sections...
# 14.0 build SZ#002412 sections
# start to analyse Day level SZ#002412 all cross sections...
# build SZ#002626 sections
# start to analyse Day level SZ#002626 all cross sections...
# 16.0 build SZ#002851 sections
# start to analyse Day level SZ#002851 all cross sections...
# build SZ#300130 sections
# start to analyse Day level SZ#300130 all cross sections...
# 18.0 build SZ#300344 sections
# start to analyse Day level SZ#300344 all cross sections...
# build SZ#300561 sections
# start to analyse Day level SZ#300561 all cross sections...
# 20.0 build SZ#000028 sections
# start to analyse Day level SZ#000028 all cross sections...
# build SZ#000681 sections
# start to analyse Day level SZ#000681 all cross sections...
# 22.0 build SZ#000987 sections
# start to analyse Day level SZ#000987 all cross sections...
# build SZ#002199 sections
# start to analyse Day level SZ#002199 all cross sections...
# 24.0 build SZ#002413 sections
# start to analyse Day level SZ#002413 all cross sections...
# build SZ#002627 sections
# start to analyse Day level SZ#002627 all cross sections...
# 26.0 build SZ#002852 sections
# start to analyse Day level SZ#002852 all cross sections...
# build SZ#300131 sections
# start to analyse Day level SZ#300131 all cross sections...
# 28.0 build SZ#300345 sections
# start to analyse Day level SZ#300345 all cross sections...
# build SZ#300562 sections
# start to analyse Day level SZ#300562 all cross sections...
# 30.0 build SZ#000029 sections
# start to analyse Day level SZ#000029 all cross sections...
# build SZ#000682 sections
# start to analyse Day level SZ#000682 all cross sections...
# 32.0 build SZ#000988 sections
# start to analyse Day level SZ#000988 all cross sections...
# build SZ#002200 sections
# start to analyse Day level SZ#002200 all cross sections...
# 34.0 build SZ#002414 sections
# start to analyse Day level SZ#002414 all cross sections...
# build SZ#002628 sections
# start to analyse Day level SZ#002628 all cross sections...
# 36.0 build SZ#002853 sections
# start to analyse Day level SZ#002853 all cross sections...
# build SZ#300132 sections
# start to analyse Day level SZ#300132 all cross sections...
# 38.0 build SZ#300346 sections
# start to analyse Day level SZ#300346 all cross sections...
# build SZ#300563 sections
# start to analyse Day level SZ#300563 all cross sections...
# 40.0 build SZ#000030 sections
# start to analyse Day level SZ#000030 all cross sections...
# build SZ#000683 sections
# start to analyse Day level SZ#000683 all cross sections...
# 42.0 build SZ#000989 sections
# start to analyse Day level SZ#000989 all cross sections...
# build SZ#002201 sections
# start to analyse Day level SZ#002201 all cross sections...
# 44.0 build SZ#002415 sections
# start to analyse Day level SZ#002415 all cross sections...
# build SZ#002629 sections
# start to analyse Day level SZ#002629 all cross sections...
# 46.0 build SZ#002855 sections
# start to analyse Day level SZ#002855 all cross sections...
# build SZ#300133 sections
# start to analyse Day level SZ#300133 all cross sections...
# 48.0 build SZ#300347 sections
# start to analyse Day level SZ#300347 all cross sections...
# build SZ#300565 sections
# start to analyse Day level SZ#300565 all cross sections...
# 50.0 build SZ#000031 sections
# start to analyse Day level SZ#000031 all cross sections...
# build SZ#000685 sections
# start to analyse Day level SZ#000685 all cross sections...
# 52.0 build SZ#000990 sections
# start to analyse Day level SZ#000990 all cross sections...
# build SZ#002202 sections
# start to analyse Day level SZ#002202 all cross sections...
# 54.0 build SZ#002416 sections
# start to analyse Day level SZ#002416 all cross sections...
# build SZ#002630 sections
# start to analyse Day level SZ#002630 all cross sections...
# 56.0 build SZ#002856 sections
# start to analyse Day level SZ#002856 all cross sections...
# build SZ#300134 sections
# start to analyse Day level SZ#300134 all cross sections...
# 58.0 build SZ#300348 sections
# start to analyse Day level SZ#300348 all cross sections...
# build SZ#300566 sections
# start to analyse Day level SZ#300566 all cross sections...
# 60.0 build SZ#000032 sections
# start to analyse Day level SZ#000032 all cross sections...
# build SZ#000686 sections
# start to analyse Day level SZ#000686 all cross sections...
# 62.0 build SZ#000993 sections
# start to analyse Day level SZ#000993 all cross sections...
# build SZ#002203 sections
# start to analyse Day level SZ#002203 all cross sections...
# 64.0 build SZ#002417 sections
# start to analyse Day level SZ#002417 all cross sections...
# build SZ#002631 sections
# start to analyse Day level SZ#002631 all cross sections...
# 66.0 build SZ#002857 sections
# start to analyse Day level SZ#002857 all cross sections...
# build SZ#300135 sections
# start to analyse Day level SZ#300135 all cross sections...
# 68.0 build SZ#300349 sections
# start to analyse Day level SZ#300349 all cross sections...
# build SZ#300567 sections
# start to analyse Day level SZ#300567 all cross sections...
# 70.0 build SZ#000034 sections
# start to analyse Day level SZ#000034 all cross sections...
# build SZ#000687 sections
# start to analyse Day level SZ#000687 all cross sections...
# 72.0 build SZ#000995 sections
# start to analyse Day level SZ#000995 all cross sections...
# build SZ#002204 sections
# start to analyse Day level SZ#002204 all cross sections...
# 74.0 build SZ#002418 sections
# start to analyse Day level SZ#002418 all cross sections...
# build SZ#002632 sections
# start to analyse Day level SZ#002632 all cross sections...
# 76.0 build SZ#002858 sections
# start to analyse Day level SZ#002858 all cross sections...
# build SZ#300136 sections
# start to analyse Day level SZ#300136 all cross sections...
# 78.0 build SZ#300350 sections
# start to analyse Day level SZ#300350 all cross sections...
# build SZ#300568 sections
# start to analyse Day level SZ#300568 all cross sections...
# 80.0 build SZ#000035 sections
# start to analyse Day level SZ#000035 all cross sections...
# build SZ#000688 sections
# start to analyse Day level SZ#000688 all cross sections...
# 82.0 build SZ#000996 sections
# start to analyse Day level SZ#000996 all cross sections...
# build SZ#002205 sections
# start to analyse Day level SZ#002205 all cross sections...
# 84.0 build SZ#002419 sections
# start to analyse Day level SZ#002419 all cross sections...
# build SZ#002633 sections
# start to analyse Day level SZ#002633 all cross sections...
# 86.0 build SZ#002859 sections
# start to analyse Day level SZ#002859 all cross sections...
# build SZ#300137 sections
# start to analyse Day level SZ#300137 all cross sections...
# 88.0 build SZ#300351 sections
# start to analyse Day level SZ#300351 all cross sections...
# build SZ#300569 sections
# start to analyse Day level SZ#300569 all cross sections...
# 90.0 build SZ#000036 sections
# start to analyse Day level SZ#000036 all cross sections...
# build SZ#000690 sections
# start to analyse Day level SZ#000690 all cross sections...
# 92.0 build SZ#000997 sections
# start to analyse Day level SZ#000997 all cross sections...
# build SZ#002206 sections
# start to analyse Day level SZ#002206 all cross sections...
# 94.0 build SZ#002420 sections
# start to analyse Day level SZ#002420 all cross sections...
# build SZ#002634 sections
# start to analyse Day level SZ#002634 all cross sections...
# 96.0 build SZ#002860 sections
# start to analyse Day level SZ#002860 all cross sections...
# build SZ#300138 sections
# start to analyse Day level SZ#300138 all cross sections...
# 98.0 build SZ#300352 sections
# start to analyse Day level SZ#300352 all cross sections...
# build SZ#300570 sections
# start to analyse Day level SZ#300570 all cross sections...
# 100.0

# %%
# %run BasicDataRebuilder.ipynb


rebuild = BasicDataRebuilder()
rebuild.rebuild_chan_data(200,300,30,60)
