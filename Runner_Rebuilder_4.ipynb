# %%
# %run BasicDataRebuilder.ipynb


rebuild = BasicDataRebuilder()
rebuild.rebuild_all_sections(400,500,30,60)
# Out:
# rebuild_all_sections get 100 symbols
# build SZ#000050 sections
# start to analyse Day level SZ#000050 all cross sections...
# build SZ#000705 sections
# start to analyse Day level SZ#000705 all cross sections...
# 2.0 build SZ#002004 sections
# start to analyse Day level SZ#002004 all cross sections...
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:52: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:74: RuntimeWarning: divide by zero encountered in double_scalars
# build SZ#002217 sections
# start to analyse Day level SZ#002217 all cross sections...
# 4.0 build SZ#002431 sections
# start to analyse Day level SZ#002431 all cross sections...
# build SZ#002645 sections
# start to analyse Day level SZ#002645 all cross sections...
# 6.0 build SZ#002871 sections
# start to analyse Day level SZ#002871 all cross sections...
# build SZ#300149 sections
# start to analyse Day level SZ#300149 all cross sections...
# 8.0 build SZ#300364 sections
# start to analyse Day level SZ#300364 all cross sections...
# build SZ#300582 sections
# start to analyse Day level SZ#300582 all cross sections...
# 10.0 build SZ#000055 sections
# start to analyse Day level SZ#000055 all cross sections...
# build SZ#000707 sections
# start to analyse Day level SZ#000707 all cross sections...
# 12.0 build SZ#002005 sections
# start to analyse Day level SZ#002005 all cross sections...
# build SZ#002218 sections
# start to analyse Day level SZ#002218 all cross sections...
# 14.0 build SZ#002432 sections
# start to analyse Day level SZ#002432 all cross sections...
# build SZ#002646 sections
# start to analyse Day level SZ#002646 all cross sections...
# 16.0 build SZ#002872 sections
# start to analyse Day level SZ#002872 all cross sections...
# build SZ#300150 sections
# start to analyse Day level SZ#300150 all cross sections...
# 18.0 build SZ#300365 sections
# start to analyse Day level SZ#300365 all cross sections...
# build SZ#300583 sections
# start to analyse Day level SZ#300583 all cross sections...
# 20.0 build SZ#000056 sections
# start to analyse Day level SZ#000056 all cross sections...
# build SZ#000708 sections
# start to analyse Day level SZ#000708 all cross sections...
# 22.0 build SZ#002006 sections
# start to analyse Day level SZ#002006 all cross sections...
# build SZ#002219 sections
# start to analyse Day level SZ#002219 all cross sections...
# 24.0 build SZ#002433 sections
# start to analyse Day level SZ#002433 all cross sections...
# build SZ#002647 sections
# start to analyse Day level SZ#002647 all cross sections...
# 26.0 build SZ#002873 sections
# start to analyse Day level SZ#002873 all cross sections...
# build SZ#300151 sections
# start to analyse Day level SZ#300151 all cross sections...
# 28.0 build SZ#300366 sections
# start to analyse Day level SZ#300366 all cross sections...
# build SZ#300584 sections
# start to analyse Day level SZ#300584 all cross sections...
# 30.0 build SZ#000058 sections
# start to analyse Day level SZ#000058 all cross sections...
# build SZ#000709 sections
# start to analyse Day level SZ#000709 all cross sections...
# 32.0 build SZ#002007 sections
# start to analyse Day level SZ#002007 all cross sections...
# build SZ#002220 sections
# start to analyse Day level SZ#002220 all cross sections...
# 34.0 build SZ#002434 sections
# start to analyse Day level SZ#002434 all cross sections...
# build SZ#002648 sections
# start to analyse Day level SZ#002648 all cross sections...
# 36.0 build SZ#002875 sections
# start to analyse Day level SZ#002875 all cross sections...
# build SZ#300152 sections
# start to analyse Day level SZ#300152 all cross sections...
# 38.0 build SZ#300367 sections
# start to analyse Day level SZ#300367 all cross sections...
# build SZ#300585 sections
# start to analyse Day level SZ#300585 all cross sections...
# 40.0 build SZ#000059 sections
# start to analyse Day level SZ#000059 all cross sections...
# build SZ#000710 sections
# start to analyse Day level SZ#000710 all cross sections...
# 42.0 build SZ#002008 sections
# start to analyse Day level SZ#002008 all cross sections...
# build SZ#002221 sections
# start to analyse Day level SZ#002221 all cross sections...
# 44.0 build SZ#002435 sections
# start to analyse Day level SZ#002435 all cross sections...
# build SZ#002649 sections
# start to analyse Day level SZ#002649 all cross sections...
# 46.0 build SZ#002876 sections
# start to analyse Day level SZ#002876 all cross sections...
# build SZ#300153 sections
# start to analyse Day level SZ#300153 all cross sections...
# 48.0 build SZ#300368 sections
# start to analyse Day level SZ#300368 all cross sections...
# build SZ#300586 sections
# start to analyse Day level SZ#300586 all cross sections...
# 50.0 build SZ#000060 sections
# start to analyse Day level SZ#000060 all cross sections...
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:52: RuntimeWarning: invalid value encountered in double_scalars
# build SZ#000711 sections
# start to analyse Day level SZ#000711 all cross sections...
# 52.0 build SZ#002009 sections
# start to analyse Day level SZ#002009 all cross sections...
# build SZ#002222 sections
# start to analyse Day level SZ#002222 all cross sections...
# 54.0 build SZ#002436 sections
# start to analyse Day level SZ#002436 all cross sections...
# build SZ#002650 sections
# start to analyse Day level SZ#002650 all cross sections...
# 56.0 build SZ#002877 sections
# start to analyse Day level SZ#002877 all cross sections...
# build SZ#300154 sections
# start to analyse Day level SZ#300154 all cross sections...
# 58.0 build SZ#300369 sections
# start to analyse Day level SZ#300369 all cross sections...
# build SZ#300587 sections
# start to analyse Day level SZ#300587 all cross sections...
# 60.0 build SZ#000061 sections
# start to analyse Day level SZ#000061 all cross sections...
# build SZ#000712 sections
# start to analyse Day level SZ#000712 all cross sections...
# 62.0 build SZ#002010 sections
# start to analyse Day level SZ#002010 all cross sections...
# build SZ#002223 sections
# start to analyse Day level SZ#002223 all cross sections...
# 64.0 build SZ#002437 sections
# start to analyse Day level SZ#002437 all cross sections...
# build SZ#002651 sections
# start to analyse Day level SZ#002651 all cross sections...
# 66.0 build SZ#002878 sections
# start to analyse Day level SZ#002878 all cross sections...
# build SZ#300155 sections
# start to analyse Day level SZ#300155 all cross sections...
# 68.0 build SZ#300370 sections
# start to analyse Day level SZ#300370 all cross sections...
# build SZ#300588 sections
# start to analyse Day level SZ#300588 all cross sections...
# 70.0 build SZ#000062 sections
# start to analyse Day level SZ#000062 all cross sections...
# build SZ#000713 sections
# start to analyse Day level SZ#000713 all cross sections...
# 72.0 build SZ#002011 sections
# start to analyse Day level SZ#002011 all cross sections...
# build SZ#002224 sections
# start to analyse Day level SZ#002224 all cross sections...
# 74.0 build SZ#002438 sections
# start to analyse Day level SZ#002438 all cross sections...
# build SZ#002652 sections
# start to analyse Day level SZ#002652 all cross sections...
# 76.0 build SZ#002879 sections
# start to analyse Day level SZ#002879 all cross sections...
# build SZ#300156 sections
# start to analyse Day level SZ#300156 all cross sections...
# 78.0 build SZ#300371 sections
# start to analyse Day level SZ#300371 all cross sections...
# build SZ#300589 sections
# start to analyse Day level SZ#300589 all cross sections...
# 80.0 build SZ#000063 sections
# start to analyse Day level SZ#000063 all cross sections...
# build SZ#000715 sections
# start to analyse Day level SZ#000715 all cross sections...
# 82.0 build SZ#002012 sections
# start to analyse Day level SZ#002012 all cross sections...
# build SZ#002225 sections
# start to analyse Day level SZ#002225 all cross sections...
# 84.0 build SZ#002439 sections
# start to analyse Day level SZ#002439 all cross sections...
# build SZ#002653 sections
# start to analyse Day level SZ#002653 all cross sections...
# 86.0 build SZ#002880 sections
# start to analyse Day level SZ#002880 all cross sections...
# build SZ#300157 sections
# start to analyse Day level SZ#300157 all cross sections...
# 88.0 build SZ#300373 sections
# start to analyse Day level SZ#300373 all cross sections...
# build SZ#300590 sections
# start to analyse Day level SZ#300590 all cross sections...
# 90.0 build SZ#000065 sections
# start to analyse Day level SZ#000065 all cross sections...
# build SZ#000716 sections
# start to analyse Day level SZ#000716 all cross sections...
# 92.0 build SZ#002013 sections
# start to analyse Day level SZ#002013 all cross sections...
# build SZ#002226 sections
# start to analyse Day level SZ#002226 all cross sections...
# 94.0 build SZ#002440 sections
# start to analyse Day level SZ#002440 all cross sections...
# build SZ#002654 sections
# start to analyse Day level SZ#002654 all cross sections...
# 96.0 build SZ#002881 sections
# start to analyse Day level SZ#002881 all cross sections...
# build SZ#300158 sections
# start to analyse Day level SZ#300158 all cross sections...
# 98.0 build SZ#300374 sections
# start to analyse Day level SZ#300374 all cross sections...
# build SZ#300591 sections
# start to analyse Day level SZ#300591 all cross sections...
# 100.0

# %%
# %run BasicDataRebuilder.ipynb


rebuild = BasicDataRebuilder()
rebuild.rebuild_chan_data(50,70,30,60)
# Out:
# rebuild chan data get 20 symbols
# 10.0 20.0 30.0 40.0 50.0 60.0 70.0 80.0 90.0 100.0
