# %%
# %run SectionManager.ipynb
# %run Constant.ipynb

print('Hello')

symbol='SZ#002022'

sm = SectionManager(symbol,level_day,30,60)

sm.build_file_path()
# Out:
# Hello
# '/Users/xinwang/stock/data/original_sections/Day/Day_30_60_sections_V0.8_SZ#002022.txt'

# %%
sm.get_all_cross_sections()
# Out:
# start to analyse Day level SZ#002022 all cross sections...
#        symbol      s_date      e_date  s_price  e_price    ampl  ma_per  \
# 1   SZ#002022  2004-12-22  2004-12-24    -0.68    -0.72   10.53   -3.28
# 2   SZ#002022  2005-03-18  2005-05-11    -0.73    -0.99   44.66   -1.33
# 3   SZ#002022  2005-07-19  2006-07-27    -0.92     1.31  322.58  255.91
# 4   SZ#002022  2006-09-22  2007-12-04     1.72     9.87  773.24  722.73
# 5   SZ#002022  2007-12-28  2008-03-27    13.04    12.10   43.09   28.26
# 6   SZ#002022  2008-05-29  2008-07-04    13.23    13.24   31.39   -4.49
# 7   SZ#002022  2008-08-07  2008-08-29    12.95    10.34   32.62   -5.55
# 8   SZ#002022  2008-12-05  2009-03-04    11.42    11.27   29.81   19.94
# 9   SZ#002022  2009-05-08  2009-08-19    11.73    10.66   52.45    9.84
# 10  SZ#002022  2009-10-09  2010-01-06    13.66    15.69   56.68   24.67
# 11  SZ#002022  2010-02-11  2010-05-10    16.39    14.92   45.92   11.24
# ...
