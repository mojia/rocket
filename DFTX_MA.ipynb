# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime


day_dir='/Users/xinwang/stock/data/day/'
week_dir='/Users/xinwang/stock/data/week/'
report_dir='/Users/xinwang/stock/data/report/'
debug=False

level_30F = '30F'
level_day = 'Day'
level_week = 'Week'
k_columns = ['date','open','high','low','close','volume','amount']
day_level_prefix='D_'
week_level_prefix='W_'

# %%
import datetime as dt


def tostr(float_number):
    return '%.2f' % float_number

def get_fix_stop_loss_percent():
    return 7


# 止损价格
def get_stop_loss_price(price):
    return price * (1-get_fix_stop_loss_percent()/100)

def buy_how_many(account_money,price):
#     单笔交易承担亏损3%
    risk_percent = 3
    risk_money = account_money*risk_percent/100
    
#     止损价格
    stop_loss_price = get_stop_loss_price(price)
    plan_shares = risk_money/(price-stop_loss_price)
    
    return int((plan_shares)/100)*100

def sell_how_many(account_shares):
    return account_shares

def out_of_range(date,start_datetime,end_datetime):
    year_s, mon_s, day_s = date.split('-')
    cur_datetime = datetime(int(year_s), int(mon_s), int(day_s))
    
    return cur_datetime<start_datetime or cur_datetime>end_datetime
    
    
def to_datetime(date_str):
    return datetime.strptime(date_str,'%Y-%m-%d') 


def to_pd_datetime(date_str):
    var_datetime = to_datetime(date_str)
    return pd.datetime(var_datetime.year,var_datetime.month,var_datetime.day)


def merge_day_k_lines_to_one_week_k(day_k_lines):
    the_first_day = day_k_lines[:1]
    the_last_day = day_k_lines[-1:]

    w_date = the_last_day['date'].values[0]
    w_open = the_first_day['open'].values[0]
    w_high = day_k_lines['high'].max()
    w_low = day_k_lines['low'].min()
    w_close = the_last_day['close'].values[0]
    w_volume = day_k_lines['volume'].sum()
    w_amount = day_k_lines['amount'].sum()

    return [w_date,w_open,w_high,w_low,w_close,w_volume,w_amount]


def get_day_k_in_that_week(cur_date,day_k):
    year = int(cur_date.split('-')[0])
    week = to_datetime(cur_date).isocalendar()[1]

    return day_k[(day_k['year']==year) & (day_k['week']==week)]


def build_week_k_advance(day_file_name):
    stock_data = pd.read_csv(day_dir+day_file_name,header=None, names=k_columns)

    period_type = 'W'
    stock_data['date'] = pd.to_datetime(stock_data['date'])

    stock_data.set_index('date',inplace=True)

    w_data = stock_data.resample(period_type).last()

    w_data['open'] = stock_data['open'].resample(period_type).first()
    w_data['high'] = stock_data['high'].resample(period_type).max()
    w_data['low'] = stock_data['low'].resample(period_type).min()
    w_data['volume'] = stock_data['volume'].resample(period_type).sum()
    w_data['amount'] = stock_data['amount'].resample(period_type).sum()

    w_data.reset_index(inplace=True)
    w_data['date'] = w_data['date'].apply(lambda x: x + dt.timedelta(days = -2))
    w_data['datetime'] = w_data['date']
    w_data['date'] = w_data['date'].apply(lambda x: x.strftime('%Y-%m-%d'))

    w_data = w_data[w_data['open'].notnull()]

    return w_data

def get_day_K(file_name):
    file = day_dir+file_name
    if(os.path.exists(file)):
        day_k = pd.read_csv(file, header=None, names=k_columns)

        day_k['datetime'] = pd.to_datetime(day_k['date'])
        day_k['year'] = day_k['date'].apply(lambda x: int(x.split('-')[0]))
        day_k['week'] = day_k['date'].apply(lambda x: to_datetime(x).isocalendar()[1])    

        return day_k
    else:
        return pd.DataFrame()
        

def get_week_K(day_k_file_name):
    original_name = day_k_file_name.split('_')[1]
    print(original_name)
    
    week_file = week_dir+ 'W_'+ original_name
    
    if(os.path.exists(week_file)):
        week_k =  pd.read_csv(week_file)
    else:
        print('No Week K ' + day_k_file_name)
        week_k = build_week_k_file_by_day_K(day_k_file_name)
    
    week_k['datetime'] = pd.to_datetime(week_k['date'])
#     week_k['year'] = week_k['date'].apply(lambda x: int(x.year))
#     week_k['week'] = week_k['date'].apply(lambda x: int(x.week))    
    
    return week_k
        

def build_week_k_file_by_day_K(day_k_file_name):
    week_k_df = build_week_k_advance(day_k_file_name)
    
    original_name = day_k_file_name.split('_')[1]
    week_file = week_dir +'W_'+ original_name
    
    week_k_df.to_csv(week_file, index=0)
    
    return week_k_df

# %%
class Metric:
            
    def __init__(self, day_k, week_k, level, short, mid):
        self.day_k = day_k
        self.week_k = week_k
        self.level = level
        self.short = short
        self.mid = mid
        
        if(self.level==level_day):
            self.data = self.day_k
        elif(self.level==level_week):
            self.data = self.week_k
        
    def previous_series(self,cur_date,latest_n):
        cur_index = self.data[self.data['date']==cur_date].index.values[0]
        start_index = cur_index.astype(int)-latest_n+1

        latest_part = self.data[start_index:cur_index+1]
            
        return latest_part
        
    def ma(self,cur_date,periods):
        periods_part = self.previous_series(cur_date, periods)['close']
        return round(periods_part.mean(),2)
    
    def std(self,cur_date, periods):
        periods_part = self.previous_series(cur_date, periods)['close']
        return np.std(periods_part)


    # {参数 N: 2，250，20 }
    # BOLL:MA(CLOSE,M); UB:BOLL+2*STD(CLOSE,M); LB:BOLL-2*STD(CLOSE,M);
    def boll(self,cur_date):
        M=20
        price = self.data[self.data['date']==cur_date]['close'].values[0]

        boll = self.ma(cur_date, M)
        up_boll = boll + 2 * (self.std(cur_date,M))
        low_boll = boll - 2 * (self.std(cur_date,M))
        return boll


    def is_on_boll(self,cur_date):
        boll_value = self.boll(cur_date)

        price = self.data[self.data['date']==cur_date]['close'].values[0]

        if(price>boll_value):
            return True
        else:
            return False
        
        
    def is_down_cross(self,cur_date):
            cur_ma_short = self.ma(cur_date,self.short)
            cur_ma_mid = self.ma(cur_date,self.mid)

            previous_part = self.previous_series(cur_date,2)
            if(len(previous_part)==0):
                return False

            last_day = previous_part['date'].values[0]

            last_day_ma_short = self.ma(last_day,self.short)
            last_day_ma_mid = self.ma(last_day,self.mid)

            if((cur_ma_short<cur_ma_mid) and (last_day_ma_short>=last_day_ma_mid)):
                return True
            else:
                return False
        
    def is_up_cross(self,cur_date):
        cur_ma_short = self.ma(cur_date,self.short)
        cur_ma_mid = self.ma(cur_date,self.mid)
  
        previous_part = self.previous_series(cur_date,2)
        if(len(previous_part)==0):
            return False
        
        last_day = previous_part['date'].values[0]
        
        last_day_ma_short = self.ma(last_day,self.short)
        last_day_ma_mid = self.ma(last_day,self.mid)
        
        if((cur_ma_short>cur_ma_mid) and (last_day_ma_short<=last_day_ma_mid)):
            return True
        else:
            return False

    def k_on_ma(self,cur_date, latest_n_k=3):
        latest_n_k_close = self.previous_series(cur_date,latest_n_k)['close']
        flag=True

        for c in latest_n_k_close:
            if(c<self.ma(cur_date,short)):
                return False

        return flag


    def latest_n_period_up_crossed(self,cur_date, latest_n=3):
        latest_part = self.previous_series(cur_date, latest_n)['date'].values

        cross_array = []
        for i in range(0,latest_n):
            date = latest_part[i]
            up_cross = self.is_up_cross(date, short, mid)

            if(up_cross == True):
                return True

        return False


    def latest_n_k_break_ma(self,cur_date, latest_n_k=3):
        latest_n_k_close = self.previous_series(cur_date,latest_n_k)['close']

        flag=True

        for c in latest_n_k_close:
            if(c>self.ma(cur_date, mid)):
                return False

        if(debug):
            print(cur_date + ' ' + str(flag))
        return flag
    
    def deep_k_break_ma(self,cur_date, deep_percent=3):
        price = self.data[self.data['date']==cur_date]['close'].values[0]
        ma_price = self.ma(cur_date, mid)
        if((ma_price-price)*100/price>deep_percent):
            return True

        return False

    def get_vol(self,cur_date):
        vol = self.data[self.data['date']==cur_date]['volume'].values[0]
        return vol

    def ma_vol(self,cur_date, periods=60):
        periods_part = self.previous_series(cur_date, periods)['volume']
        return periods_part.mean()

    def is_vol_outburst_point(self,cur_date, threshold=2, periods=60):
        vol = self.get_vol(cur_date)
        ma_vol_num = self.ma_vol(cur_date, periods)
        vol_rate = vol/ ma_vol_num

        if(vol_rate>threshold):
            return True
        else:
            return False

    # LARGE_VOL = SUM(VOL,5)/5/MA(VOL,60)    
    def is_latest_n_vol_outburst(self,cur_date, latest_n=5, threshold=2, periods=60):
        latest_part = self.previous_series(cur_date,latest_n)

        sum_vol = sum(latest_part['volume'])

        vol_rate = sum_vol/latest_n/self.ma_vol(cur_date, periods)

        if(vol_rate>threshold):
            return True
        else:
            return False


    # LARGE_VOL:=SUM(VOL,5)/5/MA(VOL,60)
    # COUNT(LARGE_VOL>2,10)>5
    # 成交量异动
    def is_outburst(self,cur_date, latest_n = 10, periods=60):
        latest_part = self.previous_series(cur_date,latest_n)

        count = 0
        for index,row in latest_part.iterrows():
            if(self.is_vol_outburst_point(row['date'])):
                count += 1

        if(count>5):
            return True
        else:
            return False

    def is_up_cross_outburst(self,cur_date, latest_n=10):
        latest_part = self.previous_series(cur_date, latest_n)

        for index,row in latest_part.iterrows():
            date = row['date']

            if(self.is_outburst(date)):
                return True

        next_part = self.next_periods_series(cur_date, latest_n)

        for index,row in next_part.iterrows():
            date = row['date']

            if(self.is_outburst(date)):
                return True

        return False
    


    def next_down_cross(self,next_sections):
        for index,row in next_sections.iterrows():
            date = row['date']
            if(self.is_down_cross(date)):
                return date

        return 'None'

    def previous_down_cross(self,next_sections):
        reverse_section = next_sections.iloc[::-1]

        for index,row in reverse_section.iterrows():
            date = row['date']
            if(self.is_down_cross(date)):
                return date

        return 'None'

# %%
class Section:
    
    def __init__(self, day_k, week_k, level, short, mid):
        self.day_k = day_k
        self.week_k = week_k
        self.level = level
        self.short = short
        self.mid = mid
        
        if(self.level==level_day):
            self.data = self.day_k
        elif(self.level==level_week):
            self.data = self.week_k
    
        self.metric = Metric(day_k, week_k, level, short, mid)
        
    
    def get_section(self,start_date_str,end_date_str):
        start = to_pd_datetime(start_date_str) 
        end = to_pd_datetime(end_date_str) 

        section = self.data[(self.data['datetime']>=start) & (self.data['datetime']<=end)]

        return section

    def get_highest_record(self,start_date,end_date):
        section = self.get_section(start_date,end_date)
        return section.loc[section['high'].idxmax()]

    def get_lowest_record(self,start_date,end_date):
        section = self.get_section(start_date,end_date)
        return section.loc[section['low'].idxmin()]

    def get_amplitude_percent(self,start_date,end_date):
        highest = self.get_highest_record(start_date,end_date)
        lowest = self.get_lowest_record(start_date,end_date)

        return round((highest['high']-lowest['low'])*100.0/lowest['low'],2)


    def how_many_periods(self,start_date,end_date):
        section = self.get_section(start_date,end_date)
        return section.shape[0]


    def get_ma_increase_per(self,start_date,end_date):        
        start_ma = self.metric.ma(start_date, self.short)
        end_ma = self.metric.ma(end_date, self.short)

        return round((end_ma-start_ma)*100.0/start_ma,2)

# %%
section_columns=['symbol','s_date','e_date','ampl','ma_per','periods','boll']

enable_day_boll_condition=True


class Report:
    section_df = pd.DataFrame(columns=section_columns)

    def __init__(self, file_name, level, short, mid):
        self.file_name = file_name
        self.day_k = get_day_K(file_name)
        self.week_k = get_week_K(file_name)
        
        self.level = level
        self.short = short
        self.mid = mid
        
        if(self.level==level_day):
            self.data = self.day_k
        elif(self.level==level_week):
            self.data = self.week_k
            
        
        self.start_date = self.data['date'][:1].values[0]
        self.end_date = self.data['date'][-1:].values[0]
        
        
        self.section_df = pd.DataFrame(columns=section_columns)
        self.section = Section(self.day_k, self.week_k, self.level, self.short, self.mid)
            
            
    def analyse_specific_day(self,cur_date):
        metric = Metric(self.day_k, self.week_k, self.level, self.short, self.mid)
        
        if(metric.is_up_cross(cur_date)):
            start = cur_date
            next_sections = self.section.get_section(start, self.end_date)
            previous_sections = self.section.get_section(self.start_date, start)

            next_down_cross_date = metric.next_down_cross(next_sections)
            
            if(next_down_cross_date == 'None'):
                return 
            
            if(debug==True):
                print('up cross:' +start + 
                      '\n down cross:' + next_down_cross_date)

            amplitude = self.section.get_amplitude_percent(start,next_down_cross_date)
            ma_percent = self.section.get_ma_increase_per(start,next_down_cross_date)
            periods = self.section.how_many_periods(start,next_down_cross_date)
            boll = metric.is_on_boll(cur_date)
            
            self.section_df.loc[self.section_df.shape[0] +1] = [self.file_name,start,next_down_cross_date,amplitude,ma_percent,periods,boll]

        
#     级别金叉，死叉，振幅，
    def analyse_up_cross_and_down_cross(self):
        all_dates = self.data['date'][self.mid:]
       
        start_datetime = to_datetime(self.start_date)
        end_datetime = to_datetime(self.end_date)

        progress = 0
        for date in all_dates:
            if(not(out_of_range(date,start_datetime,end_datetime))):
                self.analyse_specific_day(date)

            progress += 1
            if(progress % 500 == 0):
                print(tostr(progress*100/len(all_dates)) + '%', end=' ')
                
        return self.section_df
    
    
    
def run_gold_rate(symbols, level, short, mid):
    report_df = pd.DataFrame(columns=section_columns)
    
    for i in range(0, len(symbols)):
        report = Report(symbols[i], level,short,mid)
        temp_section = report.analyse_up_cross_and_down_cross()

        report_df = pd.concat([temp_section,report_df], ignore_index=True)
        
        for threshold in [60,70,80,90,100]:
            ampl_count = report_df[report_df['ampl']>threshold].shape[0]
            total = report_df.shape[0]
            if(total>0):
                rate = 100*ampl_count/total
                print('threshold '+ str(threshold) + ', ampl size:'+ str(ampl_count) +
                      ' total size:'+str(total) + ' rate ' +str(rate))
        print('------------------------- '+ str((i+1)*100.0/len(symbols)) +'% ---------------------------')
        
    now_str = datetime.now().strftime('%Y-%m-%d_%H:%M')
    report_df.to_csv(report_dir+level + '_' + now_str +'_report_df.csv',index=0)
    
    return report_df


symbols = ['D_SZ#000713.txt','D_SZ#002065.txt','D_SZ#002333.txt','D_SZ#002601.txt',
           'D_SZ#002882.txt','D_SZ#300207.txt','D_SZ#300476.txt',
           'D_SZ#000715.txt','D_SZ#002066.txt','D_SZ#002334.txt',
           'D_SZ#002602.txt','D_SZ#002883.txt','D_SZ#300208.txt','D_SZ#300477.txt',
           'D_SZ#000716.txt','D_SZ#002067.txt','D_SZ#002335.txt',
           'D_SZ#002603.txt','D_SZ#002884.txt','D_SZ#300209.txt','D_SZ#300478.txt',
           'D_SZ#000717.txt','D_SZ#002068.txt','D_SZ#002336.txt',
           'D_SZ#002604.txt','D_SZ#002885.txt','D_SZ#300210.txt','D_SZ#300479.txt',
           'D_SZ#000718.txt','D_SZ#002069.txt','D_SZ#002337.txt',
           'D_SZ#002605.txt','D_SZ#002886.txt','D_SZ#300211.txt','D_SZ#300480.txt',
           'D_SZ#300760.txt','D_SZ#000719.txt','D_SZ#002070.txt','D_SZ#002338.txt',
           'D_SZ#002606.txt','D_SZ#002887.txt','D_SZ#300212.txt','D_SZ#300481.txt',
           'D_SZ#000650.txt','D_SZ#002015.txt','D_SZ#002282.txt','D_SZ#002549.txt',
           'D_SZ#002825.txt','D_SZ#300159.txt','D_SZ#300428.txt','D_SZ#300701.txt',
           'D_SZ#000651.txt','D_SZ#002016.txt','D_SZ#002283.txt','D_SZ#002550.txt',
           'D_SZ#002826.txt','D_SZ#300160.txt','D_SZ#300429.txt','D_SZ#300702.txt',
           'D_SZ#000652.txt','D_SZ#002017.txt','D_SZ#002284.txt','D_SZ#002551.txt',
           'D_SZ#002827.txt','D_SZ#300161.txt','D_SZ#300430.txt','D_SZ#300703.txt',
           'D_SZ#000655.txt','D_SZ#002018.txt','D_SZ#002285.txt','D_SZ#002552.txt',
           'D_SZ#002828.txt','D_SZ#300162.txt','D_SZ#300431.txt','D_SZ#300705.txt',
           'D_SZ#000656.txt','D_SZ#002019.txt','D_SZ#002286.txt','D_SZ#002553.txt',
           'D_SZ#002829.txt','D_SZ#300163.txt','D_SZ#300432.txt','D_SZ#300706.txt',
           'D_SZ#000657.txt','D_SZ#002020.txt','D_SZ#002287.txt','D_SZ#002554.txt',
           'D_SZ#002830.txt','D_SZ#300164.txt','D_SZ#300433.txt','D_SZ#300707.txt',
           'D_SZ#000659.txt','D_SZ#002021.txt','D_SZ#002288.txt','D_SZ#002555.txt',
           'D_SZ#002831.txt','D_SZ#300165.txt','D_SZ#300434.txt','D_SZ#300708.txt',
           'D_SZ#000661.txt','D_SZ#002022.txt','D_SZ#002289.txt','D_SZ#002556.txt',
           'D_SZ#002832.txt','D_SZ#300166.txt','D_SZ#300435.txt','D_SZ#300709.txt',
           'D_SZ#000662.txt','D_SZ#002023.txt','D_SZ#002290.txt','D_SZ#002557.txt',
           'D_SZ#002833.txt','D_SZ#300167.txt','D_SZ#300436.txt','D_SZ#300710.txt',
           'D_SZ#000663.txt','D_SZ#002024.txt','D_SZ#002291.txt','D_SZ#002558.txt',
           'D_SZ#002835.txt','D_SZ#300168.txt','D_SZ#300437.txt','D_SZ#300711.txt']
# symbols = ['D_SZ#002022.txt']


day_report_df = run_gold_rate(symbols,level_day,short=30, mid=60)
day_report_df

week_report_df = run_gold_rate(symbols,level_week,short=30, mid=60)
week_report_df



def find_all_day_sections_between(symbol, start_date, end_date):
    start_datetime = to_datetime(start_date)
    end_datetime = to_datetime(end_date)
    
    day_report_df['s_datetime'] = pd.to_datetime(day_report_df['s_date'])
    
    part = day_report_df[(day_report_df['symbol']==symbol) & (day_report_df['s_datetime']>=start_datetime) & (day_report_df['s_datetime']<=end_datetime)]

    return part
    

def week_cross_and_day_cross():
    symbols = week_report_df['symbol'].drop_duplicates()
    
    ampl_df = pd.DataFrame(columns=['symbol','w_s_date','w_e_date','d_s_date','d_e_date','ampl','d_boll'])
    
    for symbol in symbols:
        dates = week_report_df[(week_report_df['symbol']==symbol)]['s_date']
        
        for date in dates:
            w_section = week_report_df[(week_report_df['symbol']==symbol) & (week_report_df['s_date']==date)]
            
            w_start_date = w_section['s_date'].values[0]
            w_end_date = w_section['e_date'].values[0]
            
            d_sections = find_all_day_sections_between(symbol, w_start_date, w_end_date)
                
            for index,row in d_sections.iterrows():
                d_s_date = row['s_date']
                d_e_date = row['e_date']
                d_ampl = row['ampl']
                d_boll = row['boll']
                
                ampl_df.loc[ampl_df.shape[0]+1] = [symbol,w_start_date, w_end_date,d_s_date,d_e_date,d_ampl,d_boll]
    
    now_str = datetime.now().strftime('%Y-%m-%d_%H:%M')
    ampl_df.to_csv(report_dir+'ampl_' + now_str +'_ampl_df.csv',index=0)
            
    return ampl_df
    
ampl_df = week_cross_and_day_cross()

print()
print('\n')
print('********************** The result ********************************')
        
for threshold in [60,70,80,90,100]:
    ampl_count = ampl_df[(ampl_df['ampl']>threshold) & (ampl_df['d_boll']==True)].shape[0]
    total = ampl_df.shape[0]
    rate = 100*ampl_count/total

    print('threshold '+ str(threshold) + ', ampl size:'+ str(ampl_count) +
          ' total size:'+str(total) + 
          ' rate ' +str(rate))
            
        
ampl_df
# Out:
# SZ#000713.txt
# 11.48% 22.96% 34.44% 45.92% 57.41% 68.89% 80.37% 91.85% threshold 60, ampl size:6 total size:38 rate 15.789473684210526
# threshold 70, ampl size:4 total size:38 rate 10.526315789473685
# threshold 80, ampl size:4 total size:38 rate 10.526315789473685
# threshold 90, ampl size:4 total size:38 rate 10.526315789473685
# threshold 100, ampl size:4 total size:38 rate 10.526315789473685
# ------------------------- 0.8130081300813008% ---------------------------
# SZ#002065.txt
# 19.20% 38.40% 57.60% 76.80% 96.01% threshold 60, ampl size:13 total size:60 rate 21.666666666666668
# threshold 70, ampl size:9 total size:60 rate 15.0
# threshold 80, ampl size:9 total size:60 rate 15.0
# threshold 90, ampl size:9 total size:60 rate 15.0
# threshold 100, ampl size:9 total size:60 rate 15.0
# ------------------------- 1.6260162601626016% ---------------------------
# SZ#002333.txt
# 23.63% 47.26% 70.89% 94.52% threshold 60, ampl size:15 total size:83 rate 18.072289156626507
# threshold 70, ampl size:11 total size:83 rate 13.25301204819277
# threshold 80, ampl size:11 total size:83 rate 13.25301204819277
# threshold 90, ampl size:11 total size:83 rate 13.25301204819277
# threshold 100, ampl size:11 total size:83 rate 13.25301204819277
# ------------------------- 2.4390243902439024% ---------------------------
# SZ#002601.txt
# 29.78% 59.56% 89.34% threshold 60, ampl size:20 total size:100 rate 20.0
# threshold 70, ampl size:16 total size:100 rate 16.0
# threshold 80, ampl size:15 total size:100 rate 15.0
# threshold 90, ampl size:15 total size:100 rate 15.0
# threshold 100, ampl size:15 total size:100 rate 15.0
# ------------------------- 3.252032520325203% ---------------------------
# SZ#002882.txt
# threshold 60, ampl size:20 total size:101 rate 19.801980198019802
# threshold 70, ampl size:16 total size:101 rate 15.841584158415841
# threshold 80, ampl size:15 total size:101 rate 14.851485148514852
# threshold 90, ampl size:15 total size:101 rate 14.851485148514852
# threshold 100, ampl size:15 total size:101 rate 14.851485148514852
# ------------------------- 4.065040650406504% ---------------------------
# SZ#300207.txt
# 27.93% 55.87% 83.80% threshold 60, ampl size:23 total size:118 rate 19.491525423728813
# threshold 70, ampl size:18 total size:118 rate 15.254237288135593
# threshold 80, ampl size:17 total size:118 rate 14.40677966101695
# threshold 90, ampl size:17 total size:118 rate 14.40677966101695
# threshold 100, ampl size:17 total size:118 rate 14.40677966101695
# ------------------------- 4.878048780487805% ---------------------------
# SZ#300476.txt
# 60.02% threshold 60, ampl size:24 total size:126 rate 19.047619047619047
# threshold 70, ampl size:19 total size:126 rate 15.079365079365079
# threshold 80, ampl size:17 total size:126 rate 13.492063492063492
# threshold 90, ampl size:17 total size:126 rate 13.492063492063492
# threshold 100, ampl size:17 total size:126 rate 13.492063492063492
# ------------------------- 5.691056910569106% ---------------------------
# SZ#000715.txt
# 11.85% 23.71% 35.56% 47.42% 59.27% 71.12% 82.98% 94.83% threshold 60, ampl size:32 total size:159 rate 20.12578616352201
# threshold 70, ampl size:25 total size:159 rate 15.723270440251572
# threshold 80, ampl size:22 total size:159 rate 13.836477987421384
# threshold 90, ampl size:21 total size:159 rate 13.20754716981132
# threshold 100, ampl size:19 total size:159 rate 11.949685534591195
# ------------------------- 6.504065040650406% ---------------------------
# SZ#002066.txt
# 16.90% 33.80% 50.69% 67.59% 84.49% threshold 60, ampl size:39 total size:188 rate 20.74468085106383
# threshold 70, ampl size:32 total size:188 rate 17.02127659574468
# threshold 80, ampl size:28 total size:188 rate 14.893617021276595
# threshold 90, ampl size:26 total size:188 rate 13.829787234042554
# threshold 100, ampl size:23 total size:188 rate 12.23404255319149
# ------------------------- 7.317073170731708% ---------------------------
# SZ#002334.txt
# 23.62% 47.24% 70.85% 94.47% threshold 60, ampl size:44 total size:208 rate 21.153846153846153
# threshold 70, ampl size:35 total size:208 rate 16.826923076923077
# threshold 80, ampl size:31 total size:208 rate 14.903846153846153
# threshold 90, ampl size:29 total size:208 rate 13.942307692307692
# threshold 100, ampl size:25 total size:208 rate 12.01923076923077
# ------------------------- 8.130081300813009% ---------------------------
# SZ#002602.txt
# 38.23% 76.45% threshold 60, ampl size:47 total size:224 rate 20.982142857142858
# threshold 70, ampl size:38 total size:224 rate 16.964285714285715
# threshold 80, ampl size:34 total size:224 rate 15.178571428571429
# threshold 90, ampl size:32 total size:224 rate 14.285714285714286
# threshold 100, ampl size:28 total size:224 rate 12.5
# ------------------------- 8.94308943089431% ---------------------------
# SZ#002883.txt
# threshold 60, ampl size:47 total size:227 rate 20.704845814977972
# threshold 70, ampl size:38 total size:227 rate 16.740088105726873
# threshold 80, ampl size:34 total size:227 rate 14.977973568281937
# threshold 90, ampl size:32 total size:227 rate 14.09691629955947
# threshold 100, ampl size:28 total size:227 rate 12.334801762114537
# ------------------------- 9.75609756097561% ---------------------------
# SZ#300208.txt
# 30.38% 60.75% 91.13% threshold 60, ampl size:50 total size:242 rate 20.66115702479339
# threshold 70, ampl size:41 total size:242 rate 16.94214876033058
# threshold 80, ampl size:35 total size:242 rate 14.462809917355372
# threshold 90, ampl size:33 total size:242 rate 13.636363636363637
# threshold 100, ampl size:29 total size:242 rate 11.983471074380166
# ------------------------- 10.56910569105691% ---------------------------
# SZ#300477.txt
# 68.40% threshold 60, ampl size:52 total size:250 rate 20.8
# threshold 70, ampl size:43 total size:250 rate 17.2
# threshold 80, ampl size:36 total size:250 rate 14.4
# threshold 90, ampl size:34 total size:250 rate 13.6
# threshold 100, ampl size:29 total size:250 rate 11.6
# ------------------------- 11.382113821138212% ---------------------------
# SZ#000716.txt
# 12.66% 25.33% 37.99% 50.66% 63.32% 75.99% 88.65% threshold 60, ampl size:61 total size:285 rate 21.403508771929825
# threshold 70, ampl size:50 total size:285 rate 17.54385964912281
# threshold 80, ampl size:40 total size:285 rate 14.035087719298245
# threshold 90, ampl size:37 total size:285 rate 12.982456140350877
# threshold 100, ampl size:32 total size:285 rate 11.228070175438596
# ------------------------- 12.195121951219512% ---------------------------
# SZ#002067.txt
# 17.11% 34.21% 51.32% 68.42% 85.53% threshold 60, ampl size:67 total size:309 rate 21.68284789644013
# threshold 70, ampl size:56 total size:309 rate 18.12297734627832
# threshold 80, ampl size:45 total size:309 rate 14.563106796116505
# threshold 90, ampl size:41 total size:309 rate 13.268608414239482
# threshold 100, ampl size:36 total size:309 rate 11.650485436893204
# ------------------------- 13.008130081300813% ---------------------------
# SZ#002335.txt
# 24.68% 49.36% 74.04% 98.72% threshold 60, ampl size:70 total size:325 rate 21.53846153846154
# threshold 70, ampl size:59 total size:325 rate 18.153846153846153
# threshold 80, ampl size:48 total size:325 rate 14.76923076923077
# threshold 90, ampl size:43 total size:325 rate 13.23076923076923
# threshold 100, ampl size:38 total size:325 rate 11.692307692307692
# ------------------------- 13.821138211382113% ---------------------------
# SZ#002603.txt
# 28.47% 56.95% 85.42% threshold 60, ampl size:71 total size:341 rate 20.821114369501466
# threshold 70, ampl size:60 total size:341 rate 17.59530791788856
# threshold 80, ampl size:49 total size:341 rate 14.36950146627566
# threshold 90, ampl size:44 total size:341 rate 12.903225806451612
# threshold 100, ampl size:39 total size:341 rate 11.436950146627566
# ------------------------- 14.634146341463415% ---------------------------
# SZ#002884.txt
# threshold 60, ampl size:71 total size:343 rate 20.699708454810494
# threshold 70, ampl size:60 total size:343 rate 17.49271137026239
# threshold 80, ampl size:49 total size:343 rate 14.285714285714286
# threshold 90, ampl size:44 total size:343 rate 12.82798833819242
# threshold 100, ampl size:39 total size:343 rate 11.370262390670554
# ------------------------- 15.447154471544716% ---------------------------
# SZ#300209.txt
# 33.07% 66.14% 99.21% threshold 60, ampl size:75 total size:360 rate 20.833333333333332
# threshold 70, ampl size:62 total size:360 rate 17.22222222222222
# threshold 80, ampl size:51 total size:360 rate 14.166666666666666
# threshold 90, ampl size:46 total size:360 rate 12.777777777777779
# threshold 100, ampl size:41 total size:360 rate 11.38888888888889
# ------------------------- 16.260162601626018% ---------------------------
# SZ#300478.txt
# 67.20% threshold 60, ampl size:76 total size:366 rate 20.76502732240437
# threshold 70, ampl size:63 total size:366 rate 17.21311475409836
# threshold 80, ampl size:52 total size:366 rate 14.207650273224044
# threshold 90, ampl size:47 total size:366 rate 12.841530054644808
# threshold 100, ampl size:41 total size:366 rate 11.202185792349727
# ------------------------- 17.073170731707318% ---------------------------
# SZ#000717.txt
# 11.39% 22.78% 34.18% 45.57% 56.96% 68.35% 79.74% 91.14% threshold 60, ampl size:85 total size:404 rate 21.03960396039604
# threshold 70, ampl size:72 total size:404 rate 17.821782178217823
# threshold 80, ampl size:58 total size:404 rate 14.356435643564357
# threshold 90, ampl size:51 total size:404 rate 12.623762376237623
# threshold 100, ampl size:45 total size:404 rate 11.138613861386139
# ------------------------- 17.88617886178862% ---------------------------
# SZ#002068.txt
# 17.14% 34.28% 51.42% 68.56% 85.70% threshold 60, ampl size:91 total size:430 rate 21.162790697674417
# threshold 70, ampl size:77 total size:430 rate 17.906976744186046
# threshold 80, ampl size:62 total size:430 rate 14.418604651162791
# threshold 90, ampl size:54 total size:430 rate 12.55813953488372
# threshold 100, ampl size:48 total size:430 rate 11.162790697674419
# ------------------------- 18.69918699186992% ---------------------------
# SZ#002336.txt
# 23.90% 47.80% 71.70% 95.60% threshold 60, ampl size:93 total size:452 rate 20.575221238938052
# threshold 70, ampl size:78 total size:452 rate 17.256637168141594
# threshold 80, ampl size:63 total size:452 rate 13.938053097345133
# threshold 90, ampl size:55 total size:452 rate 12.168141592920353
# threshold 100, ampl size:49 total size:452 rate 10.84070796460177
# ------------------------- 19.51219512195122% ---------------------------
# SZ#002604.txt
# 31.71% 63.41% 95.12% threshold 60, ampl size:94 total size:465 rate 20.21505376344086
# threshold 70, ampl size:79 total size:465 rate 16.989247311827956
# threshold 80, ampl size:64 total size:465 rate 13.763440860215054
# threshold 90, ampl size:56 total size:465 rate 12.043010752688172
# threshold 100, ampl size:50 total size:465 rate 10.75268817204301
# ------------------------- 20.32520325203252% ---------------------------
# SZ#002885.txt
# threshold 60, ampl size:95 total size:467 rate 20.342612419700213
# threshold 70, ampl size:80 total size:467 rate 17.130620985010708
# threshold 80, ampl size:64 total size:467 rate 13.704496788008566
# threshold 90, ampl size:56 total size:467 rate 11.991434689507495
# threshold 100, ampl size:50 total size:467 rate 10.70663811563169
# ------------------------- 21.13821138211382% ---------------------------
# SZ#300210.txt
# 27.89% 55.77% 83.66% threshold 60, ampl size:98 total size:483 rate 20.28985507246377
# threshold 70, ampl size:82 total size:483 rate 16.977225672877847
# threshold 80, ampl size:65 total size:483 rate 13.457556935817806
# threshold 90, ampl size:57 total size:483 rate 11.801242236024844
# threshold 100, ampl size:51 total size:483 rate 10.559006211180124
# ------------------------- 21.951219512195124% ---------------------------
# SZ#300479.txt
# 67.20% threshold 60, ampl size:99 total size:490 rate 20.20408163265306
# threshold 70, ampl size:83 total size:490 rate 16.93877551020408
# threshold 80, ampl size:66 total size:490 rate 13.46938775510204
# threshold 90, ampl size:58 total size:490 rate 11.83673469387755
# threshold 100, ampl size:52 total size:490 rate 10.612244897959183
# ------------------------- 22.764227642276424% ---------------------------
# SZ#000718.txt
# 12.04% 24.08%
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: divide by zero encountered in double_scalars
# 36.13% 48.17% 60.21% 72.25% 84.30% 96.34% threshold 60, ampl size:108 total size:529 rate 20.415879017013232
# threshold 70, ampl size:90 total size:529 rate 17.013232514177695
# threshold 80, ampl size:72 total size:529 rate 13.610586011342155
# threshold 90, ampl size:64 total size:529 rate 12.098298676748582
# threshold 100, ampl size:58 total size:529 rate 10.964083175803403
# ------------------------- 23.577235772357724% ---------------------------
# SZ#002069.txt
# 18.12% 36.23% 54.35% 72.46% 90.58% threshold 60, ampl size:114 total size:553 rate 20.61482820976492
# threshold 70, ampl size:96 total size:553 rate 17.359855334538878
# threshold 80, ampl size:77 total size:553 rate 13.924050632911392
# threshold 90, ampl size:68 total size:553 rate 12.296564195298373
# threshold 100, ampl size:62 total size:553 rate 11.211573236889693
# ------------------------- 24.390243902439025% ---------------------------
# SZ#002337.txt
# 23.81% 47.62% 71.43% 95.24% threshold 60, ampl size:116 total size:574 rate 20.209059233449477
# threshold 70, ampl size:97 total size:574 rate 16.898954703832754
# threshold 80, ampl size:78 total size:574 rate 13.588850174216027
# threshold 90, ampl size:69 total size:574 rate 12.020905923344948
# threshold 100, ampl size:63 total size:574 rate 10.975609756097562
# ------------------------- 25.203252032520325% ---------------------------
# SZ#002605.txt
# 31.09% 62.19% 93.28% threshold 60, ampl size:119 total size:591 rate 20.135363790186126
# threshold 70, ampl size:99 total size:591 rate 16.751269035532996
# threshold 80, ampl size:80 total size:591 rate 13.536379018612521
# threshold 90, ampl size:71 total size:591 rate 12.013536379018612
# threshold 100, ampl size:64 total size:591 rate 10.829103214890017
# ------------------------- 26.016260162601625% ---------------------------
# SZ#002886.txt
# threshold 60, ampl size:120 total size:594 rate 20.2020202020202
# threshold 70, ampl size:99 total size:594 rate 16.666666666666668
# threshold 80, ampl size:80 total size:594 rate 13.468013468013469
# threshold 90, ampl size:71 total size:594 rate 11.952861952861953
# threshold 100, ampl size:64 total size:594 rate 10.774410774410775
# ------------------------- 26.829268292682926% ---------------------------
# SZ#300211.txt
# 27.67% 55.34% 83.01% threshold 60, ampl size:124 total size:614 rate 20.19543973941368
# threshold 70, ampl size:102 total size:614 rate 16.612377850162865
# threshold 80, ampl size:83 total size:614 rate 13.517915309446254
# threshold 90, ampl size:74 total size:614 rate 12.052117263843648
# threshold 100, ampl size:67 total size:614 rate 10.912052117263844
# ------------------------- 27.642276422764226% ---------------------------
# SZ#300480.txt
# 66.05% threshold 60, ampl size:125 total size:620 rate 20.161290322580644
# threshold 70, ampl size:103 total size:620 rate 16.612903225806452
# threshold 80, ampl size:83 total size:620 rate 13.387096774193548
# threshold 90, ampl size:74 total size:620 rate 11.935483870967742
# threshold 100, ampl size:67 total size:620 rate 10.806451612903226
# ------------------------- 28.45528455284553% ---------------------------
# SZ#300760.txt
# threshold 60, ampl size:125 total size:620 rate 20.161290322580644
# threshold 70, ampl size:103 total size:620 rate 16.612903225806452
# threshold 80, ampl size:83 total size:620 rate 13.387096774193548
# threshold 90, ampl size:74 total size:620 rate 11.935483870967742
# threshold 100, ampl size:67 total size:620 rate 10.806451612903226
# ------------------------- 29.26829268292683% ---------------------------
# SZ#000719.txt
# 15.05% 30.09% 45.14% 60.19% 75.23% 90.28% threshold 60, ampl size:131 total size:648 rate 20.21604938271605
# threshold 70, ampl size:108 total size:648 rate 16.666666666666668
# threshold 80, ampl size:88 total size:648 rate 13.580246913580247
# threshold 90, ampl size:79 total size:648 rate 12.191358024691358
# threshold 100, ampl size:71 total size:648 rate 10.95679012345679
# ------------------------- 30.08130081300813% ---------------------------
# SZ#002070.txt
# 22.50% 45.00% 67.51% 90.01% threshold 60, ampl size:137 total size:664 rate 20.632530120481928
# threshold 70, ampl size:113 total size:664 rate 17.018072289156628
# threshold 80, ampl size:92 total size:664 rate 13.855421686746988
# threshold 90, ampl size:83 total size:664 rate 12.5
# threshold 100, ampl size:75 total size:664 rate 11.295180722891565
# ------------------------- 30.89430894308943% ---------------------------
# SZ#002338.txt
# 23.72% 47.44% 71.16% 94.88% threshold 60, ampl size:141 total size:684 rate 20.614035087719298
# threshold 70, ampl size:115 total size:684 rate 16.81286549707602
# threshold 80, ampl size:94 total size:684 rate 13.742690058479532
# threshold 90, ampl size:85 total size:684 rate 12.426900584795321
# threshold 100, ampl size:77 total size:684 rate 11.257309941520468
# ------------------------- 31.70731707317073% ---------------------------
# SZ#002606.txt
# 32.20% 64.39% 96.59% threshold 60, ampl size:145 total size:695 rate 20.863309352517987
# threshold 70, ampl size:118 total size:695 rate 16.97841726618705
# threshold 80, ampl size:97 total size:695 rate 13.956834532374101
# threshold 90, ampl size:87 total size:695 rate 12.517985611510792
# threshold 100, ampl size:79 total size:695 rate 11.366906474820144
# ------------------------- 32.520325203252035% ---------------------------
# SZ#002887.txt
# threshold 60, ampl size:145 total size:696 rate 20.833333333333332
# threshold 70, ampl size:118 total size:696 rate 16.95402298850575
# threshold 80, ampl size:97 total size:696 rate 13.936781609195402
# threshold 90, ampl size:87 total size:696 rate 12.5
# threshold 100, ampl size:79 total size:696 rate 11.350574712643677
# ------------------------- 33.333333333333336% ---------------------------
# SZ#300212.txt
# 30.32% 60.64% 90.96% threshold 60, ampl size:150 total size:712 rate 21.06741573033708
# threshold 70, ampl size:123 total size:712 rate 17.275280898876403
# threshold 80, ampl size:101 total size:712 rate 14.185393258426966
# threshold 90, ampl size:91 total size:712 rate 12.780898876404494
# threshold 100, ampl size:81 total size:712 rate 11.376404494382022
# ------------------------- 34.146341463414636% ---------------------------
# SZ#300481.txt
# 62.11% threshold 60, ampl size:152 total size:720 rate 21.11111111111111
# threshold 70, ampl size:124 total size:720 rate 17.22222222222222
# threshold 80, ampl size:102 total size:720 rate 14.166666666666666
# threshold 90, ampl size:92 total size:720 rate 12.777777777777779
# threshold 100, ampl size:82 total size:720 rate 11.38888888888889
# ------------------------- 34.959349593495936% ---------------------------
# SZ#000650.txt
# 11.93% 23.85% 35.78% 47.71% 59.64% 71.56% 83.49% 95.42% threshold 60, ampl size:161 total size:756 rate 21.296296296296298
# threshold 70, ampl size:133 total size:756 rate 17.59259259259259
# threshold 80, ampl size:109 total size:756 rate 14.417989417989418
# threshold 90, ampl size:98 total size:756 rate 12.962962962962964
# threshold 100, ampl size:88 total size:756 rate 11.640211640211641
# ------------------------- 35.77235772357724% ---------------------------
# SZ#002015.txt
# 17.25% 34.49% 51.74% 68.99% 86.24% threshold 60, ampl size:167 total size:789 rate 21.166032953105198
# threshold 70, ampl size:139 total size:789 rate 17.61723700887199
# threshold 80, ampl size:114 total size:789 rate 14.448669201520913
# threshold 90, ampl size:101 total size:789 rate 12.801013941698352
# threshold 100, ampl size:90 total size:789 rate 11.406844106463879
# ------------------------- 36.58536585365854% ---------------------------
# SZ#002282.txt
# 23.97% 47.94% 71.91% 95.88% threshold 60, ampl size:171 total size:808 rate 21.163366336633665
# threshold 70, ampl size:143 total size:808 rate 17.698019801980198
# threshold 80, ampl size:118 total size:808 rate 14.603960396039604
# threshold 90, ampl size:104 total size:808 rate 12.871287128712872
# threshold 100, ampl size:93 total size:808 rate 11.509900990099009
# ------------------------- 37.39837398373984% ---------------------------
# SZ#002549.txt
# 28.18% 56.37% 84.55% threshold 60, ampl size:175 total size:828 rate 21.135265700483092
# threshold 70, ampl size:145 total size:828 rate 17.51207729468599
# threshold 80, ampl size:120 total size:828 rate 14.492753623188406
# threshold 90, ampl size:105 total size:828 rate 12.681159420289855
# threshold 100, ampl size:94 total size:828 rate 11.352657004830919
# ------------------------- 38.21138211382114% ---------------------------
# SZ#002825.txt
# threshold 60, ampl size:175 total size:831 rate 21.0589651022864
# threshold 70, ampl size:145 total size:831 rate 17.448856799037305
# threshold 80, ampl size:120 total size:831 rate 14.440433212996389
# threshold 90, ampl size:105 total size:831 rate 12.635379061371841
# threshold 100, ampl size:94 total size:831 rate 11.311672683513839
# ------------------------- 39.02439024390244% ---------------------------
# SZ#300159.txt
# 28.51% 57.01% 85.52% threshold 60, ampl size:177 total size:848 rate 20.87264150943396
# threshold 70, ampl size:146 total size:848 rate 17.21698113207547
# threshold 80, ampl size:121 total size:848 rate 14.268867924528301
# threshold 90, ampl size:106 total size:848 rate 12.5
# threshold 100, ampl size:95 total size:848 rate 11.202830188679245
# ------------------------- 39.83739837398374% ---------------------------
# SZ#300428.txt
# 68.97% threshold 60, ampl size:179 total size:856 rate 20.911214953271028
# threshold 70, ampl size:147 total size:856 rate 17.172897196261683
# threshold 80, ampl size:121 total size:856 rate 14.13551401869159
# threshold 90, ampl size:106 total size:856 rate 12.383177570093459
# threshold 100, ampl size:95 total size:856 rate 11.098130841121495
# ------------------------- 40.65040650406504% ---------------------------
# SZ#300701.txt
# threshold 60, ampl size:179 total size:859 rate 20.838183934807915
# threshold 70, ampl size:147 total size:859 rate 17.11292200232829
# threshold 80, ampl size:121 total size:859 rate 14.086146682188591
# threshold 90, ampl size:106 total size:859 rate 12.339930151338766
# threshold 100, ampl size:95 total size:859 rate 11.059371362048894
# ------------------------- 41.46341463414634% ---------------------------
# SZ#000651.txt
# 11.51% 23.03% 34.54% 46.05% 57.56% 69.08% 80.59% 92.10% threshold 60, ampl size:187 total size:904 rate 20.6858407079646
# threshold 70, ampl size:153 total size:904 rate 16.924778761061948
# threshold 80, ampl size:125 total size:904 rate 13.827433628318584
# threshold 90, ampl size:110 total size:904 rate 12.168141592920353
# threshold 100, ampl size:99 total size:904 rate 10.951327433628318
# ------------------------- 42.27642276422764% ---------------------------
# SZ#002016.txt
# 14.96% 29.91% 44.87% 59.83% 74.78% 89.74% threshold 60, ampl size:204 total size:935 rate 21.818181818181817
# threshold 70, ampl size:167 total size:935 rate 17.86096256684492
# threshold 80, ampl size:138 total size:935 rate 14.759358288770054
# threshold 90, ampl size:120 total size:935 rate 12.834224598930481
# threshold 100, ampl size:108 total size:935 rate 11.550802139037433
# ------------------------- 43.08943089430894% ---------------------------
# SZ#002283.txt
# 23.88% 47.76% 71.63% 95.51% threshold 60, ampl size:207 total size:953 rate 21.720881427072403
# threshold 70, ampl size:170 total size:953 rate 17.83840503672613
# threshold 80, ampl size:141 total size:953 rate 14.795383001049318
# threshold 90, ampl size:123 total size:953 rate 12.906610703043022
# threshold 100, ampl size:110 total size:953 rate 11.54249737670514
# ------------------------- 43.90243902439025% ---------------------------
# SZ#002550.txt
# 26.60% 53.19% 79.79% threshold 60, ampl size:210 total size:972 rate 21.604938271604937
# threshold 70, ampl size:173 total size:972 rate 17.79835390946502
# threshold 80, ampl size:144 total size:972 rate 14.814814814814815
# threshold 90, ampl size:124 total size:972 rate 12.757201646090534
# threshold 100, ampl size:111 total size:972 rate 11.419753086419753
# ------------------------- 44.71544715447155% ---------------------------
# SZ#002826.txt
# threshold 60, ampl size:210 total size:976 rate 21.516393442622952
# threshold 70, ampl size:173 total size:976 rate 17.725409836065573
# threshold 80, ampl size:144 total size:976 rate 14.754098360655737
# threshold 90, ampl size:124 total size:976 rate 12.704918032786885
# threshold 100, ampl size:111 total size:976 rate 11.37295081967213
# ------------------------- 45.52845528455285% ---------------------------
# SZ#300160.txt
# 27.28% 54.56% 81.83% threshold 60, ampl size:214 total size:997 rate 21.464393179538614
# threshold 70, ampl size:176 total size:997 rate 17.65295887662989
# threshold 80, ampl size:147 total size:997 rate 14.744232698094283
# threshold 90, ampl size:127 total size:997 rate 12.738214643931796
# threshold 100, ampl size:114 total size:997 rate 11.43430290872618
# ------------------------- 46.34146341463415% ---------------------------
# SZ#300429.txt
# 62.74% threshold 60, ampl size:215 total size:1001 rate 21.47852147852148
# threshold 70, ampl size:177 total size:1001 rate 17.68231768231768
# threshold 80, ampl size:147 total size:1001 rate 14.685314685314685
# threshold 90, ampl size:127 total size:1001 rate 12.687312687312687
# threshold 100, ampl size:114 total size:1001 rate 11.38861138861139
# ------------------------- 47.15447154471545% ---------------------------
# SZ#300702.txt
# threshold 60, ampl size:215 total size:1002 rate 21.457085828343313
# threshold 70, ampl size:177 total size:1002 rate 17.664670658682635
# threshold 80, ampl size:147 total size:1002 rate 14.67065868263473
# threshold 90, ampl size:127 total size:1002 rate 12.674650698602795
# threshold 100, ampl size:114 total size:1002 rate 11.377245508982035
# ------------------------- 47.96747967479675% ---------------------------
# SZ#000652.txt
# 11.70% 23.39% 35.09% 46.78% 58.48% 70.18% 81.87% 93.57% threshold 60, ampl size:221 total size:1039 rate 21.270452358036575
# threshold 70, ampl size:182 total size:1039 rate 17.51684311838306
# threshold 80, ampl size:152 total size:1039 rate 14.629451395572666
# threshold 90, ampl size:132 total size:1039 rate 12.704523580365736
# threshold 100, ampl size:118 total size:1039 rate 11.357074109720886
# ------------------------- 48.78048780487805% ---------------------------
# SZ#002017.txt
# 14.65% 29.29% 43.94% 58.58% 73.23% 87.87% threshold 60, ampl size:230 total size:1071 rate 21.475256769374415
# threshold 70, ampl size:188 total size:1071 rate 17.553688141923438
# threshold 80, ampl size:158 total size:1071 rate 14.752567693744165
# threshold 90, ampl size:137 total size:1071 rate 12.791783380018675
# threshold 100, ampl size:122 total size:1071 rate 11.391223155929039
# ------------------------- 49.59349593495935% ---------------------------
# SZ#002284.txt
# 22.75% 45.50% 68.24% 90.99% threshold 60, ampl size:235 total size:1089 rate 21.57943067033976
# threshold 70, ampl size:192 total size:1089 rate 17.63085399449036
# threshold 80, ampl size:162 total size:1089 rate 14.87603305785124
# threshold 90, ampl size:139 total size:1089 rate 12.764003673094582
# threshold 100, ampl size:123 total size:1089 rate 11.294765840220386
# ------------------------- 50.40650406504065% ---------------------------
# SZ#002551.txt
# 29.00% 58.00% 87.01% threshold 60, ampl size:237 total size:1104 rate 21.467391304347824
# threshold 70, ampl size:194 total size:1104 rate 17.57246376811594
# threshold 80, ampl size:164 total size:1104 rate 14.855072463768115
# threshold 90, ampl size:141 total size:1104 rate 12.771739130434783
# threshold 100, ampl size:125 total size:1104 rate 11.322463768115941
# ------------------------- 51.21951219512195% ---------------------------
# SZ#002827.txt
# threshold 60, ampl size:237 total size:1109 rate 21.370604147880975
# threshold 70, ampl size:194 total size:1109 rate 17.493237150586115
# threshold 80, ampl size:164 total size:1109 rate 14.78809738503156
# threshold 90, ampl size:141 total size:1109 rate 12.714156898106403
# threshold 100, ampl size:125 total size:1109 rate 11.27141568981064
# ------------------------- 52.03252032520325% ---------------------------
# SZ#300161.txt
# 29.55% 59.10% 88.65% threshold 60, ampl size:240 total size:1126 rate 21.314387211367674
# threshold 70, ampl size:197 total size:1126 rate 17.4955595026643
# threshold 80, ampl size:166 total size:1126 rate 14.742451154529308
# threshold 90, ampl size:142 total size:1126 rate 12.61101243339254
# threshold 100, ampl size:126 total size:1126 rate 11.190053285968029
# ------------------------- 52.84552845528455% ---------------------------
# SZ#300430.txt
# 60.61% threshold 60, ampl size:241 total size:1133 rate 21.270962047661076
# threshold 70, ampl size:198 total size:1133 rate 17.475728155339805
# threshold 80, ampl size:166 total size:1133 rate 14.651368049426301
# threshold 90, ampl size:142 total size:1133 rate 12.533097969991173
# threshold 100, ampl size:126 total size:1133 rate 11.120917917034422
# ------------------------- 53.65853658536585% ---------------------------
# SZ#300703.txt
# threshold 60, ampl size:242 total size:1135 rate 21.3215859030837
# threshold 70, ampl size:199 total size:1135 rate 17.53303964757709
# threshold 80, ampl size:167 total size:1135 rate 14.713656387665198
# threshold 90, ampl size:142 total size:1135 rate 12.51101321585903
# threshold 100, ampl size:126 total size:1135 rate 11.101321585903083
# ------------------------- 54.47154471544715% ---------------------------
# SZ#000655.txt
# 11.85% 23.70% 35.55% 47.39% 59.24% 71.09% 82.94% 94.79% threshold 60, ampl size:249 total size:1177 rate 21.155480033984706
# threshold 70, ampl size:206 total size:1177 rate 17.502124044180118
# threshold 80, ampl size:173 total size:1177 rate 14.69838572642311
# threshold 90, ampl size:147 total size:1177 rate 12.489379779099405
# threshold 100, ampl size:131 total size:1177 rate 11.12999150382328
# ------------------------- 55.28455284552845% ---------------------------
# SZ#002018.txt
# 16.04% 32.08% 48.12% 64.16% 80.21% 96.25% threshold 60, ampl size:255 total size:1208 rate 21.10927152317881
# threshold 70, ampl size:212 total size:1208 rate 17.549668874172184
# threshold 80, ampl size:179 total size:1208 rate 14.817880794701987
# threshold 90, ampl size:149 total size:1208 rate 12.334437086092715
# threshold 100, ampl size:133 total size:1208 rate 11.009933774834437
# ------------------------- 56.09756097560975% ---------------------------
# SZ#002285.txt
# 22.57% 45.15% 67.72% 90.29% threshold 60, ampl size:261 total size:1227 rate 21.271393643031786
# threshold 70, ampl size:216 total size:1227 rate 17.6039119804401
# threshold 80, ampl size:182 total size:1227 rate 14.832925835370823
# threshold 90, ampl size:152 total size:1227 rate 12.387938060309699
# threshold 100, ampl size:136 total size:1227 rate 11.083944580277098
# ------------------------- 56.91056910569106% ---------------------------
# SZ#002552.txt
# 27.70% 55.40% 83.10% threshold 60, ampl size:262 total size:1245 rate 21.044176706827308
# threshold 70, ampl size:217 total size:1245 rate 17.429718875502008
# threshold 80, ampl size:183 total size:1245 rate 14.698795180722891
# threshold 90, ampl size:153 total size:1245 rate 12.289156626506024
# threshold 100, ampl size:137 total size:1245 rate 11.004016064257028
# ------------------------- 57.72357723577236% ---------------------------
# SZ#002828.txt
# threshold 60, ampl size:263 total size:1248 rate 21.07371794871795
# threshold 70, ampl size:218 total size:1248 rate 17.46794871794872
# threshold 80, ampl size:184 total size:1248 rate 14.743589743589743
# threshold 90, ampl size:153 total size:1248 rate 12.259615384615385
# threshold 100, ampl size:137 total size:1248 rate 10.977564102564102
# ------------------------- 58.53658536585366% ---------------------------
# SZ#300162.txt
# 28.64% 57.27% 85.91% threshold 60, ampl size:270 total size:1266 rate 21.327014218009477
# threshold 70, ampl size:222 total size:1266 rate 17.53554502369668
# threshold 80, ampl size:187 total size:1266 rate 14.770932069510268
# threshold 90, ampl size:155 total size:1266 rate 12.243285939968404
# threshold 100, ampl size:138 total size:1266 rate 10.90047393364929
# ------------------------- 59.34959349593496% ---------------------------
# SZ#300431.txt
# 75.87% threshold 60, ampl size:271 total size:1271 rate 21.32179386309992
# threshold 70, ampl size:223 total size:1271 rate 17.54523996852872
# threshold 80, ampl size:188 total size:1271 rate 14.791502753737214
# threshold 90, ampl size:156 total size:1271 rate 12.273800157356412
# threshold 100, ampl size:138 total size:1271 rate 10.85759244689221
# ------------------------- 60.16260162601626% ---------------------------
# SZ#300705.txt
# threshold 60, ampl size:272 total size:1273 rate 21.366849960722703
# threshold 70, ampl size:224 total size:1273 rate 17.596229379418695
# threshold 80, ampl size:188 total size:1273 rate 14.768263943440692
# threshold 90, ampl size:156 total size:1273 rate 12.25451688923802
# threshold 100, ampl size:138 total size:1273 rate 10.840534171249018
# ------------------------- 60.97560975609756% ---------------------------
# SZ#000656.txt
# 12.30% 24.61% 36.91% 49.21% 61.52% 73.82% 86.12% 98.43% threshold 60, ampl size:285 total size:1311 rate 21.73913043478261
# threshold 70, ampl size:235 total size:1311 rate 17.925247902364607
# threshold 80, ampl size:198 total size:1311 rate 15.102974828375286
# threshold 90, ampl size:165 total size:1311 rate 12.585812356979405
# threshold 100, ampl size:145 total size:1311 rate 11.060259344012204
# ------------------------- 61.78861788617886% ---------------------------
# SZ#002019.txt
# 15.02% 30.04% 45.06% 60.08% 75.10% 90.12% threshold 60, ampl size:300 total size:1340 rate 22.388059701492537
# threshold 70, ampl size:246 total size:1340 rate 18.35820895522388
# threshold 80, ampl size:207 total size:1340 rate 15.447761194029852
# threshold 90, ampl size:174 total size:1340 rate 12.985074626865671
# threshold 100, ampl size:153 total size:1340 rate 11.417910447761194
# ------------------------- 62.60162601626016% ---------------------------
# SZ#002286.txt
# 24.05% 48.10% 72.15% 96.20% threshold 60, ampl size:301 total size:1361 rate 22.116091109478326
# threshold 70, ampl size:247 total size:1361 rate 18.148420279206466
# threshold 80, ampl size:208 total size:1361 rate 15.282880235121235
# threshold 90, ampl size:175 total size:1361 rate 12.858192505510655
# threshold 100, ampl size:154 total size:1361 rate 11.315209404849375
# ------------------------- 63.41463414634146% ---------------------------
# SZ#002553.txt
# 28.52% 57.05% 85.57% threshold 60, ampl size:305 total size:1381 rate 22.085445329471398
# threshold 70, ampl size:251 total size:1381 rate 18.17523533671253
# threshold 80, ampl size:211 total size:1381 rate 15.278783490224475
# threshold 90, ampl size:177 total size:1381 rate 12.81679942070963
# threshold 100, ampl size:156 total size:1381 rate 11.296162201303403
# ------------------------- 64.22764227642277% ---------------------------
# SZ#002829.txt
# threshold 60, ampl size:305 total size:1385 rate 22.021660649819495
# threshold 70, ampl size:251 total size:1385 rate 18.12274368231047
# threshold 80, ampl size:211 total size:1385 rate 15.234657039711191
# threshold 90, ampl size:177 total size:1385 rate 12.779783393501805
# threshold 100, ampl size:156 total size:1385 rate 11.263537906137184
# ------------------------- 65.04065040650407% ---------------------------
# SZ#300163.txt
# 33.40% 66.80% threshold 60, ampl size:311 total size:1399 rate 22.230164403145103
# threshold 70, ampl size:253 total size:1399 rate 18.084345961401002
# threshold 80, ampl size:213 total size:1399 rate 15.225160829163688
# threshold 90, ampl size:179 total size:1399 rate 12.794853466761973
# threshold 100, ampl size:158 total size:1399 rate 11.293781272337384
# ------------------------- 65.85365853658537% ---------------------------
# SZ#300432.txt
# 61.80% threshold 60, ampl size:312 total size:1406 rate 22.190611664295876
# threshold 70, ampl size:254 total size:1406 rate 18.06543385490754
# threshold 80, ampl size:213 total size:1406 rate 15.149359886201992
# threshold 90, ampl size:179 total size:1406 rate 12.731152204836416
# threshold 100, ampl size:158 total size:1406 rate 11.2375533428165
# ------------------------- 66.66666666666667% ---------------------------
# SZ#300706.txt
# threshold 60, ampl size:312 total size:1407 rate 22.174840085287848
# threshold 70, ampl size:254 total size:1407 rate 18.052594171997157
# threshold 80, ampl size:213 total size:1407 rate 15.138592750533048
# threshold 90, ampl size:179 total size:1407 rate 12.722103766879886
# threshold 100, ampl size:158 total size:1407 rate 11.22956645344705
# ------------------------- 67.47967479674797% ---------------------------
# SZ#000657.txt
# 14.26% 28.52% 42.78% 57.05% 71.31% 85.57% 99.83% threshold 60, ampl size:318 total size:1443 rate 22.037422037422036
# threshold 70, ampl size:259 total size:1443 rate 17.94871794871795
# threshold 80, ampl size:218 total size:1443 rate 15.107415107415108
# threshold 90, ampl size:184 total size:1443 rate 12.751212751212751
# threshold 100, ampl size:162 total size:1443 rate 11.226611226611226
# ------------------------- 68.29268292682927% ---------------------------
# SZ#002020.txt
# 15.01% 30.01% 45.02% 60.02% 75.03% 90.04% threshold 60, ampl size:330 total size:1479 rate 22.31237322515213
# threshold 70, ampl size:268 total size:1479 rate 18.120351588911426
# threshold 80, ampl size:224 total size:1479 rate 15.145368492224476
# threshold 90, ampl size:188 total size:1479 rate 12.711291413116971
# threshold 100, ampl size:166 total size:1479 rate 11.223799864773495
# ------------------------- 69.10569105691057% ---------------------------
# SZ#002287.txt
# 22.43% 44.86% 67.29% 89.73% threshold 60, ampl size:334 total size:1501 rate 22.251832111925385
# threshold 70, ampl size:270 total size:1501 rate 17.98800799467022
# threshold 80, ampl size:226 total size:1501 rate 15.056628914057296
# threshold 90, ampl size:190 total size:1501 rate 12.658227848101266
# threshold 100, ampl size:168 total size:1501 rate 11.192538307794804
# ------------------------- 69.91869918699187% ---------------------------
# SZ#002554.txt
# 27.07% 54.14% 81.21% threshold 60, ampl size:337 total size:1517 rate 22.21489782465392
# threshold 70, ampl size:273 total size:1517 rate 17.996044825313117
# threshold 80, ampl size:228 total size:1517 rate 15.029663810151614
# threshold 90, ampl size:192 total size:1517 rate 12.656558998022412
# threshold 100, ampl size:170 total size:1517 rate 11.206328279499012
# ------------------------- 70.73170731707317% ---------------------------
# SZ#002830.txt
# threshold 60, ampl size:338 total size:1520 rate 22.236842105263158
# threshold 70, ampl size:274 total size:1520 rate 18.026315789473685
# threshold 80, ampl size:229 total size:1520 rate 15.06578947368421
# threshold 90, ampl size:193 total size:1520 rate 12.697368421052632
# threshold 100, ampl size:170 total size:1520 rate 11.18421052631579
# ------------------------- 71.54471544715447% ---------------------------
# SZ#300164.txt
# 31.08% 62.15% 93.23% threshold 60, ampl size:341 total size:1538 rate 22.171651495448636
# threshold 70, ampl size:275 total size:1538 rate 17.88036410923277
# threshold 80, ampl size:229 total size:1538 rate 14.889466840052016
# threshold 90, ampl size:193 total size:1538 rate 12.548764629388817
# threshold 100, ampl size:170 total size:1538 rate 11.053315994798439
# ------------------------- 72.35772357723577% ---------------------------
# SZ#300433.txt
# 57.34% threshold 60, ampl size:341 total size:1545 rate 22.071197411003237
# threshold 70, ampl size:275 total size:1545 rate 17.79935275080906
# threshold 80, ampl size:229 total size:1545 rate 14.822006472491909
# threshold 90, ampl size:193 total size:1545 rate 12.491909385113269
# threshold 100, ampl size:170 total size:1545 rate 11.003236245954692
# ------------------------- 73.17073170731707% ---------------------------
# SZ#300707.txt
# threshold 60, ampl size:342 total size:1547 rate 22.107304460245636
# threshold 70, ampl size:276 total size:1547 rate 17.8409825468649
# threshold 80, ampl size:229 total size:1547 rate 14.802844214608921
# threshold 90, ampl size:193 total size:1547 rate 12.475759534583064
# threshold 100, ampl size:170 total size:1547 rate 10.989010989010989
# ------------------------- 73.98373983739837% ---------------------------
# SZ#000659.txt
# 11.47% 22.95% 34.42% 45.89% 57.37% 68.84% 80.31% 91.79% threshold 60, ampl size:349 total size:1585 rate 22.018927444794954
# threshold 70, ampl size:281 total size:1585 rate 17.728706624605678
# threshold 80, ampl size:233 total size:1585 rate 14.700315457413248
# threshold 90, ampl size:196 total size:1585 rate 12.365930599369085
# threshold 100, ampl size:173 total size:1585 rate 10.914826498422713
# ------------------------- 74.79674796747967% ---------------------------
# SZ#002021.txt
# 16.31% 32.62% 48.92% 65.23% 81.54% 97.85% threshold 60, ampl size:359 total size:1614 rate 22.242874845105327
# threshold 70, ampl size:288 total size:1614 rate 17.843866171003718
# threshold 80, ampl size:238 total size:1614 rate 14.745972738537795
# threshold 90, ampl size:200 total size:1614 rate 12.391573729863692
# threshold 100, ampl size:176 total size:1614 rate 10.90458488228005
# ------------------------- 75.60975609756098% ---------------------------
# SZ#002288.txt
# 24.20% 48.40% 72.60% 96.81% threshold 60, ampl size:362 total size:1634 rate 22.15422276621787
# threshold 70, ampl size:291 total size:1634 rate 17.809057527539778
# threshold 80, ampl size:240 total size:1634 rate 14.687882496940025
# threshold 90, ampl size:201 total size:1634 rate 12.30110159118727
# threshold 100, ampl size:177 total size:1634 rate 10.832313341493268
# ------------------------- 76.42276422764228% ---------------------------
# SZ#002555.txt
# 31.41% 62.81% 94.22% threshold 60, ampl size:365 total size:1650 rate 22.12121212121212
# threshold 70, ampl size:294 total size:1650 rate 17.818181818181817
# threshold 80, ampl size:243 total size:1650 rate 14.727272727272727
# threshold 90, ampl size:203 total size:1650 rate 12.303030303030303
# threshold 100, ampl size:179 total size:1650 rate 10.848484848484848
# ------------------------- 77.23577235772358% ---------------------------
# SZ#002831.txt
# threshold 60, ampl size:365 total size:1653 rate 22.081064730792498
# threshold 70, ampl size:294 total size:1653 rate 17.78584392014519
# threshold 80, ampl size:243 total size:1653 rate 14.7005444646098
# threshold 90, ampl size:203 total size:1653 rate 12.280701754385966
# threshold 100, ampl size:179 total size:1653 rate 10.828796128251664
# ------------------------- 78.04878048780488% ---------------------------
# SZ#300165.txt
# 29.45% 58.89% 88.34% threshold 60, ampl size:368 total size:1671 rate 22.022740873728306
# threshold 70, ampl size:297 total size:1671 rate 17.7737881508079
# threshold 80, ampl size:246 total size:1671 rate 14.721723518850988
# threshold 90, ampl size:206 total size:1671 rate 12.327947336923998
# threshold 100, ampl size:181 total size:1671 rate 10.83183722321963
# ------------------------- 78.86178861788618% ---------------------------
# SZ#300434.txt
# 66.84% threshold 60, ampl size:370 total size:1679 rate 22.0369267421084
# threshold 70, ampl size:299 total size:1679 rate 17.80821917808219
# threshold 80, ampl size:248 total size:1679 rate 14.770696843359142
# threshold 90, ampl size:208 total size:1679 rate 12.38832638475283
# threshold 100, ampl size:183 total size:1679 rate 10.899344848123883
# ------------------------- 79.67479674796748% ---------------------------
# SZ#300708.txt
# threshold 60, ampl size:370 total size:1682 rate 21.997621878715815
# threshold 70, ampl size:299 total size:1682 rate 17.776456599286565
# threshold 80, ampl size:248 total size:1682 rate 14.74435196195006
# threshold 90, ampl size:208 total size:1682 rate 12.366230677764566
# threshold 100, ampl size:183 total size:1682 rate 10.879904875148632
# ------------------------- 80.48780487804878% ---------------------------
# SZ#000661.txt
# 11.22% 22.44% 33.65% 44.87% 56.09% 67.31% 78.53% 89.75% threshold 60, ampl size:376 total size:1722 rate 21.835075493612077
# threshold 70, ampl size:305 total size:1722 rate 17.711962833914054
# threshold 80, ampl size:251 total size:1722 rate 14.576074332171894
# threshold 90, ampl size:210 total size:1722 rate 12.195121951219512
# threshold 100, ampl size:184 total size:1722 rate 10.685249709639953
# ------------------------- 81.30081300813008% ---------------------------
# SZ#002022.txt
# 14.67% 29.33% 44.00% 58.67% 73.34% 88.00% threshold 60, ampl size:382 total size:1754 rate 21.7787913340935
# threshold 70, ampl size:308 total size:1754 rate 17.559863169897376
# threshold 80, ampl size:253 total size:1754 rate 14.424173318129988
# threshold 90, ampl size:212 total size:1754 rate 12.086659064994299
# threshold 100, ampl size:186 total size:1754 rate 10.604332953249715
# ------------------------- 82.11382113821138% ---------------------------
# SZ#002289.txt
# 27.76% 55.52% 83.29% threshold 60, ampl size:387 total size:1772 rate 21.839729119638825
# threshold 70, ampl size:311 total size:1772 rate 17.55079006772009
# threshold 80, ampl size:255 total size:1772 rate 14.390519187358917
# threshold 90, ampl size:213 total size:1772 rate 12.020316027088036
# threshold 100, ampl size:187 total size:1772 rate 10.553047404063205
# ------------------------- 82.92682926829268% ---------------------------
# SZ#002556.txt
# 26.81% 53.62% 80.43% threshold 60, ampl size:391 total size:1789 rate 21.8557853549469
# threshold 70, ampl size:315 total size:1789 rate 17.607602012297374
# threshold 80, ampl size:259 total size:1789 rate 14.477361654555617
# threshold 90, ampl size:215 total size:1789 rate 12.017887087758524
# threshold 100, ampl size:189 total size:1789 rate 10.564561207378423
# ------------------------- 83.73983739837398% ---------------------------
# SZ#002832.txt
# threshold 60, ampl size:391 total size:1793 rate 21.80702732849972
# threshold 70, ampl size:315 total size:1793 rate 17.568321249302844
# threshold 80, ampl size:259 total size:1793 rate 14.445064138315672
# threshold 90, ampl size:215 total size:1793 rate 11.991076408254322
# threshold 100, ampl size:189 total size:1793 rate 10.540992749581706
# ------------------------- 84.55284552845528% ---------------------------
# SZ#300166.txt
# 29.92% 59.84% 89.77% threshold 60, ampl size:393 total size:1807 rate 21.74875484228002
# threshold 70, ampl size:317 total size:1807 rate 17.542888765910348
# threshold 80, ampl size:261 total size:1807 rate 14.443829551743221
# threshold 90, ampl size:217 total size:1807 rate 12.00885445489762
# threshold 100, ampl size:191 total size:1807 rate 10.57000553403431
# ------------------------- 85.36585365853658% ---------------------------
# SZ#300435.txt
# 56.75% threshold 60, ampl size:394 total size:1813 rate 21.731936017650302
# threshold 70, ampl size:318 total size:1813 rate 17.539988968560397
# threshold 80, ampl size:261 total size:1813 rate 14.396028681742967
# threshold 90, ampl size:217 total size:1813 rate 11.96911196911197
# threshold 100, ampl size:191 total size:1813 rate 10.535024820739107
# ------------------------- 86.17886178861788% ---------------------------
# SZ#300709.txt
# threshold 60, ampl size:394 total size:1814 rate 21.719955898566703
# threshold 70, ampl size:318 total size:1814 rate 17.5303197353914
# threshold 80, ampl size:261 total size:1814 rate 14.388092613009922
# threshold 90, ampl size:217 total size:1814 rate 11.962513781697906
# threshold 100, ampl size:191 total size:1814 rate 10.529217199558985
# ------------------------- 86.99186991869918% ---------------------------
# SZ#000662.txt
# 12.13% 24.25% 36.38% 48.51% 60.64% 72.76% 84.89% 97.02% threshold 60, ampl size:402 total size:1847 rate 21.765024363833245
# threshold 70, ampl size:323 total size:1847 rate 17.48781808337845
# threshold 80, ampl size:266 total size:1847 rate 14.401732539252842
# threshold 90, ampl size:221 total size:1847 rate 11.965349214943151
# threshold 100, ampl size:194 total size:1847 rate 10.503519220357337
# ------------------------- 87.8048780487805% ---------------------------
# SZ#002023.txt
# 14.60% 29.20% 43.80% 58.39% 72.99% 87.59% threshold 60, ampl size:411 total size:1878 rate 21.884984025559106
# ...
# threshold 90, ampl size:138 total size:243 rate 56.79012345679013
# threshold 100, ampl size:131 total size:243 rate 53.90946502057613
# ------------------------- 81.30081300813008% ---------------------------
# SZ#002022.txt
# 74.18% threshold 60, ampl size:173 total size:249 rate 69.47791164658635
# threshold 70, ampl size:161 total size:249 rate 64.65863453815261
# threshold 80, ampl size:146 total size:249 rate 58.63453815261044
# threshold 90, ampl size:140 total size:249 rate 56.22489959839358
# threshold 100, ampl size:132 total size:249 rate 53.01204819277108
# ------------------------- 82.11382113821138% ---------------------------
# SZ#002289.txt
# threshold 60, ampl size:176 total size:252 rate 69.84126984126983
# threshold 70, ampl size:162 total size:252 rate 64.28571428571429
# threshold 80, ampl size:147 total size:252 rate 58.333333333333336
# threshold 90, ampl size:141 total size:252 rate 55.95238095238095
# threshold 100, ampl size:133 total size:252 rate 52.77777777777778
# ------------------------- 82.92682926829268% ---------------------------
# SZ#002556.txt
# threshold 60, ampl size:179 total size:255 rate 70.19607843137256
# threshold 70, ampl size:164 total size:255 rate 64.31372549019608
# threshold 80, ampl size:149 total size:255 rate 58.431372549019606
# threshold 90, ampl size:143 total size:255 rate 56.07843137254902
# threshold 100, ampl size:135 total size:255 rate 52.94117647058823
# ------------------------- 83.73983739837398% ---------------------------
# SZ#002832.txt
# threshold 60, ampl size:180 total size:256 rate 70.3125
# threshold 70, ampl size:165 total size:256 rate 64.453125
# threshold 80, ampl size:149 total size:256 rate 58.203125
# threshold 90, ampl size:143 total size:256 rate 55.859375
# threshold 100, ampl size:135 total size:256 rate 52.734375
# ------------------------- 84.55284552845528% ---------------------------
# SZ#300166.txt
# threshold 60, ampl size:182 total size:258 rate 70.54263565891473
# threshold 70, ampl size:167 total size:258 rate 64.72868217054264
# threshold 80, ampl size:151 total size:258 rate 58.52713178294574
# threshold 90, ampl size:145 total size:258 rate 56.201550387596896
# threshold 100, ampl size:136 total size:258 rate 52.713178294573645
# ------------------------- 85.36585365853658% ---------------------------
# SZ#300435.txt
# threshold 60, ampl size:182 total size:258 rate 70.54263565891473
# threshold 70, ampl size:167 total size:258 rate 64.72868217054264
# threshold 80, ampl size:151 total size:258 rate 58.52713178294574
# threshold 90, ampl size:145 total size:258 rate 56.201550387596896
# threshold 100, ampl size:136 total size:258 rate 52.713178294573645
# ------------------------- 86.17886178861788% ---------------------------
# SZ#300709.txt
# threshold 60, ampl size:182 total size:258 rate 70.54263565891473
# threshold 70, ampl size:167 total size:258 rate 64.72868217054264
# threshold 80, ampl size:151 total size:258 rate 58.52713178294574
# threshold 90, ampl size:145 total size:258 rate 56.201550387596896
# threshold 100, ampl size:136 total size:258 rate 52.713178294573645
# ------------------------- 86.99186991869918% ---------------------------
# SZ#000662.txt
# 60.10% threshold 60, ampl size:188 total size:268 rate 70.14925373134328
# threshold 70, ampl size:172 total size:268 rate 64.17910447761194
# threshold 80, ampl size:154 total size:268 rate 57.46268656716418
# threshold 90, ampl size:148 total size:268 rate 55.223880597014926
# threshold 100, ampl size:139 total size:268 rate 51.865671641791046
# ------------------------- 87.8048780487805% ---------------------------
# SZ#002023.txt
# 73.75% threshold 60, ampl size:192 total size:273 rate 70.32967032967034
# threshold 70, ampl size:176 total size:273 rate 64.46886446886447
# threshold 80, ampl size:157 total size:273 rate 57.50915750915751
# threshold 90, ampl size:151 total size:273 rate 55.311355311355314
# threshold 100, ampl size:142 total size:273 rate 52.014652014652015
# ------------------------- 88.6178861788618% ---------------------------
# SZ#002290.txt
# threshold 60, ampl size:194 total size:277 rate 70.03610108303249
# threshold 70, ampl size:178 total size:277 rate 64.25992779783394
# threshold 80, ampl size:159 total size:277 rate 57.40072202166065
# threshold 90, ampl size:153 total size:277 rate 55.234657039711195
# threshold 100, ampl size:144 total size:277 rate 51.985559566787
# ------------------------- 89.4308943089431% ---------------------------
# SZ#002557.txt
# threshold 60, ampl size:196 total size:279 rate 70.25089605734767
# threshold 70, ampl size:180 total size:279 rate 64.51612903225806
# threshold 80, ampl size:161 total size:279 rate 57.70609318996416
# threshold 90, ampl size:154 total size:279 rate 55.19713261648746
# threshold 100, ampl size:145 total size:279 rate 51.971326164874554
# ------------------------- 90.2439024390244% ---------------------------
# SZ#002833.txt
# threshold 60, ampl size:196 total size:279 rate 70.25089605734767
# threshold 70, ampl size:180 total size:279 rate 64.51612903225806
# threshold 80, ampl size:161 total size:279 rate 57.70609318996416
# threshold 90, ampl size:154 total size:279 rate 55.19713261648746
# threshold 100, ampl size:145 total size:279 rate 51.971326164874554
# ------------------------- 91.0569105691057% ---------------------------
# SZ#300167.txt
# threshold 60, ampl size:197 total size:281 rate 70.1067615658363
# threshold 70, ampl size:181 total size:281 rate 64.41281138790036
# threshold 80, ampl size:162 total size:281 rate 57.65124555160142
# threshold 90, ampl size:155 total size:281 rate 55.16014234875445
# threshold 100, ampl size:146 total size:281 rate 51.95729537366548
# ------------------------- 91.869918699187% ---------------------------
# SZ#300436.txt
# threshold 60, ampl size:197 total size:281 rate 70.1067615658363
# threshold 70, ampl size:181 total size:281 rate 64.41281138790036
# threshold 80, ampl size:162 total size:281 rate 57.65124555160142
# threshold 90, ampl size:155 total size:281 rate 55.16014234875445
# threshold 100, ampl size:146 total size:281 rate 51.95729537366548
# ------------------------- 92.6829268292683% ---------------------------
# SZ#300710.txt
# threshold 60, ampl size:197 total size:281 rate 70.1067615658363
# threshold 70, ampl size:181 total size:281 rate 64.41281138790036
# threshold 80, ampl size:162 total size:281 rate 57.65124555160142
# threshold 90, ampl size:155 total size:281 rate 55.16014234875445
# threshold 100, ampl size:146 total size:281 rate 51.95729537366548
# ------------------------- 93.4959349593496% ---------------------------
# SZ#000663.txt
# 57.94% threshold 60, ampl size:203 total size:288 rate 70.48611111111111
# threshold 70, ampl size:187 total size:288 rate 64.93055555555556
# threshold 80, ampl size:166 total size:288 rate 57.638888888888886
# threshold 90, ampl size:159 total size:288 rate 55.208333333333336
# threshold 100, ampl size:150 total size:288 rate 52.083333333333336
# ------------------------- 94.3089430894309% ---------------------------
# SZ#002024.txt
# 73.75% threshold 60, ampl size:206 total size:294 rate 70.06802721088435
# threshold 70, ampl size:190 total size:294 rate 64.62585034013605
# threshold 80, ampl size:169 total size:294 rate 57.48299319727891
# threshold 90, ampl size:162 total size:294 rate 55.10204081632653
# threshold 100, ampl size:152 total size:294 rate 51.70068027210884
# ------------------------- 95.1219512195122% ---------------------------
# SZ#002291.txt
# threshold 60, ampl size:208 total size:298 rate 69.79865771812081
# threshold 70, ampl size:192 total size:298 rate 64.42953020134229
# threshold 80, ampl size:171 total size:298 rate 57.38255033557047
# threshold 90, ampl size:164 total size:298 rate 55.033557046979865
# threshold 100, ampl size:154 total size:298 rate 51.67785234899329
# ------------------------- 95.9349593495935% ---------------------------
# SZ#002558.txt
# threshold 60, ampl size:209 total size:300 rate 69.66666666666667
# threshold 70, ampl size:193 total size:300 rate 64.33333333333333
# threshold 80, ampl size:172 total size:300 rate 57.333333333333336
# threshold 90, ampl size:165 total size:300 rate 55.0
# threshold 100, ampl size:155 total size:300 rate 51.666666666666664
# ------------------------- 96.7479674796748% ---------------------------
# SZ#002835.txt
# threshold 60, ampl size:209 total size:300 rate 69.66666666666667
# threshold 70, ampl size:193 total size:300 rate 64.33333333333333
# threshold 80, ampl size:172 total size:300 rate 57.333333333333336
# threshold 90, ampl size:165 total size:300 rate 55.0
# threshold 100, ampl size:155 total size:300 rate 51.666666666666664
# ------------------------- 97.5609756097561% ---------------------------
# SZ#300168.txt
# threshold 60, ampl size:211 total size:303 rate 69.63696369636963
# threshold 70, ampl size:195 total size:303 rate 64.35643564356435
# threshold 80, ampl size:174 total size:303 rate 57.42574257425743
# threshold 90, ampl size:167 total size:303 rate 55.115511551155116
# threshold 100, ampl size:157 total size:303 rate 51.81518151815182
# ------------------------- 98.3739837398374% ---------------------------
# SZ#300437.txt
# threshold 60, ampl size:211 total size:304 rate 69.40789473684211
# threshold 70, ampl size:195 total size:304 rate 64.14473684210526
# threshold 80, ampl size:174 total size:304 rate 57.23684210526316
# threshold 90, ampl size:167 total size:304 rate 54.93421052631579
# threshold 100, ampl size:157 total size:304 rate 51.64473684210526
# ------------------------- 99.1869918699187% ---------------------------
# SZ#300711.txt
# threshold 60, ampl size:211 total size:304 rate 69.40789473684211
# threshold 70, ampl size:195 total size:304 rate 64.14473684210526
# threshold 80, ampl size:174 total size:304 rate 57.23684210526316
# threshold 90, ampl size:167 total size:304 rate 54.93421052631579
# threshold 100, ampl size:157 total size:304 rate 51.64473684210526
# ------------------------- 100.0% ---------------------------
#
#
#
# ********************** The result ********************************
# threshold 60, ampl size:208 total size:747 rate 27.84471218206158
# threshold 70, ampl size:169 total size:747 rate 22.623828647925034
# threshold 80, ampl size:149 total size:747 rate 19.946452476572958
# threshold 90, ampl size:125 total size:747 rate 16.733601070950467
# threshold 100, ampl size:117 total size:747 rate 15.662650602409638
#               symbol    w_s_date    w_e_date    d_s_date    d_e_date    ampl  \
# 1    D_SZ#300168.txt  2012-05-11  2012-06-29  2012-06-08  2012-11-07   38.74
# 2    D_SZ#300168.txt  2012-08-24  2016-04-01  2013-01-09  2013-10-30  168.12
# 3    D_SZ#300168.txt  2012-08-24  2016-04-01  2014-02-11  2014-07-15   46.25
# 4    D_SZ#300168.txt  2012-08-24  2016-04-01  2014-08-28  2015-07-23  708.07
# 5    D_SZ#300168.txt  2012-08-24  2016-04-01  2016-02-04  2016-02-17   15.57
# 6    D_SZ#300168.txt  2012-08-24  2016-04-01  2016-02-25  2016-03-10   45.13
# 7    D_SZ#300168.txt  2012-08-24  2016-04-01  2016-03-18  2016-03-24   12.62
# 8    D_SZ#002558.txt  2013-05-24  2017-10-27  2013-06-14  2013-07-31   22.46
# 9    D_SZ#002558.txt  2013-05-24  2017-10-27  2013-10-11  2014-01-24   41.97
# 10   D_SZ#002558.txt  2013-05-24  2017-10-27  2014-07-07  2016-02-16  944.68
# 11   D_SZ#002558.txt  2013-05-24  2017-10-27  2016-06-28  2017-01-05   52.26
# 12   D_SZ#002558.txt  2013-05-24  2017-10-27  2017-02-07  2017-05-09   55.86
# 13   D_SZ#002291.txt  2014-02-28  2016-03-18  2014-03-03  2014-05-08   14.89
# 14   D_SZ#002291.txt  2014-02-28  2016-03-18  2014-07-14  2014-12-15   43.58
# 15   D_SZ#002291.txt  2014-02-28  2016-03-18  2014-12-26  2015-02-10   12.67
# 16   D_SZ#002291.txt  2014-02-28  2016-03-18  2015-03-05  2015-07-30  194.00
# 17   D_SZ#002291.txt  2014-02-28  2016-03-18  2015-11-03  2016-01-25   72.84
# 18   D_SZ#002291.txt  2016-12-16  2017-09-29  2017-09-28  2017-11-06   30.98
# 19   D_SZ#002024.txt  2009-07-10  2011-06-17  2009-10-13  2010-02-08   36.23
# 20   D_SZ#002024.txt  2009-07-10  2011-06-17  2010-04-13  2010-04-29   21.26
# 21   D_SZ#002024.txt  2009-07-10  2011-06-17  2010-07-05  2010-11-23   61.22
# 22   D_SZ#002024.txt  2009-07-10  2011-06-17  2011-03-11  2011-04-28   14.61
# 23   D_SZ#002024.txt  2013-09-27  2014-07-04  2014-02-20  2014-03-19   52.41
# 24   D_SZ#002024.txt  2013-09-27  2014-07-04  2014-07-02  2014-07-24    7.89
# 25   D_SZ#002024.txt  2015-01-30  2016-03-04  2015-11-11  2015-12-18   31.86
# 26   D_SZ#002024.txt  2017-03-03  2017-06-30  2017-06-21  2017-12-07   47.73
# 27   D_SZ#002024.txt  2017-06-09  2017-06-30  2017-06-21  2017-12-07   47.73
# 28   D_SZ#002024.txt  2017-10-13  2018-12-07  2018-01-25  2018-03-12   23.11
# 29   D_SZ#002024.txt  2017-10-13  2018-12-07  2018-03-29  2018-07-18   32.01
# 30   D_SZ#000663.txt  2006-03-24  2008-08-15  2006-10-19  2006-11-08   23.77
# ..               ...         ...         ...         ...         ...     ...
# 718  D_SZ#002333.txt  2013-11-22  2017-11-24  2015-12-30  2016-01-18   33.94
# 719  D_SZ#002333.txt  2013-11-22  2017-11-24  2016-03-14  2016-05-23   22.28
# 720  D_SZ#002333.txt  2013-11-22  2017-11-24  2016-07-26  2017-05-12  110.71
# 721  D_SZ#002333.txt  2013-11-22  2017-11-24  2017-01-09  2017-05-12   54.96
# 722  D_SZ#002333.txt  2013-11-22  2017-11-24  2017-01-12  2017-05-12   54.96
# 723  D_SZ#002333.txt  2013-11-22  2017-11-24  2017-08-16  2017-11-03   37.77
# 724  D_SZ#002333.txt  2018-06-29  2018-10-12  2018-07-27  2018-09-12   23.44
# 725  D_SZ#002065.txt  2009-05-08  2011-06-10  2009-08-05  2010-03-22  157.86
# 726  D_SZ#002065.txt  2009-05-08  2011-06-10  2010-04-21  2010-06-09   43.89
# 727  D_SZ#002065.txt  2009-05-08  2011-06-10  2010-08-24  2011-01-17   44.25
# 728  D_SZ#002065.txt  2012-03-02  2013-01-04  2012-03-20  2012-10-30   36.59
# 729  D_SZ#002065.txt  2012-03-02  2013-01-04  2012-05-11  2012-10-30   36.59
# 730  D_SZ#002065.txt  2012-03-02  2013-01-04  2012-05-15  2012-10-30   36.59
# 731  D_SZ#002065.txt  2013-06-21  2015-12-18  2014-06-25  2014-12-01   35.84
# 732  D_SZ#002065.txt  2013-06-21  2015-12-18  2015-01-13  2015-07-13  149.79
# 733  D_SZ#002065.txt  2013-06-21  2015-12-18  2015-11-11  2016-07-19   27.27
# 734  D_SZ#002065.txt  2017-03-31  2017-06-16  2017-03-31  2017-05-17   19.09
# 735  D_SZ#000713.txt  2006-05-12  2008-12-05  2006-10-09  2006-11-22   39.03
# 736  D_SZ#000713.txt  2006-05-12  2008-12-05  2007-01-04  2007-07-02  203.96
# 737  D_SZ#000713.txt  2006-05-12  2008-12-05  2007-08-24  2007-11-07   45.91
# 738  D_SZ#000713.txt  2006-05-12  2008-12-05  2008-01-04  2008-04-25  132.69
# 739  D_SZ#000713.txt  2006-05-12  2008-12-05  2008-06-02  2008-06-19   42.03
# 740  D_SZ#000713.txt  2009-07-03  2011-09-09  2009-07-21  2009-08-28   38.34
# 741  D_SZ#000713.txt  2009-07-03  2011-09-09  2009-11-09  2010-04-09   59.24
# 742  D_SZ#000713.txt  2009-07-03  2011-09-09  2010-04-28  2010-04-29    7.09
# 743  D_SZ#000713.txt  2009-07-03  2011-09-09  2010-05-05  2010-05-17   37.23
# 744  D_SZ#000713.txt  2009-07-03  2011-09-09  2010-07-29  2011-01-25   63.88
# 745  D_SZ#000713.txt  2009-07-03  2011-09-09  2011-03-10  2011-04-18   16.56
# 746  D_SZ#000713.txt  2009-07-03  2011-09-09  2011-08-12  2011-09-28   30.74
# 747  D_SZ#000713.txt  2015-02-06  2016-01-08  2015-11-12  2016-01-21   59.36
#
#     d_boll
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18   False
# 19    True
# 20    True
# 21   False
# 22    True
# 23    True
# 24   False
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30   False
# ..     ...
# 718   True
# 719   True
# 720   True
# 721   True
# 722  False
# 723   True
# 724   True
# 725   True
# 726   True
# 727   True
# 728  False
# 729   True
# 730   True
# 731  False
# 732   True
# 733   True
# 734  False
# 735   True
# 736  False
# 737   True
# 738   True
# 739  False
# 740  False
# 741   True
# 742   True
# 743   True
# 744   True
# 745  False
# 746   True
# 747   True
#
# [747 rows x 7 columns]

# %%
day_boll_df = day_report_df[day_report_df['boll']==True]

print(day_boll_df.shape[0])
for threshold in [60,70,80,90,100]:
    ampl_count = day_boll_df[(day_boll_df['ampl']>threshold)].shape[0]
    total = day_boll_df.shape[0]
    rate = 100*ampl_count/total

    print('threshold '+ str(threshold) + ', ampl size:'+ str(ampl_count) +
          ' total size:'+str(total) + 
          ' rate ' +str(rate))
# Out:
# 1528
# threshold 60, ampl size:389 total size:1528 rate 25.458115183246072
# threshold 70, ampl size:315 total size:1528 rate 20.615183246073297
# threshold 80, ampl size:262 total size:1528 rate 17.146596858638745
# threshold 90, ampl size:224 total size:1528 rate 14.659685863874346
# threshold 100, ampl size:197 total size:1528 rate 12.892670157068062

# %%
def get_score_by_year_period_profits(year_period_profits):
    win_period = 0

    for i in range(0,len(year_period_profits)):
#         该年盈利百分比大于10%算为一个盈利年
        if(year_period_profits[i]>10):
            win_period += 1
            
#         该年盈利百分比大于10%算为一个盈利年
        if(year_period_profits[i]<-10):
            win_period -= 1
    
    return int(win_period*100/len(year_period_profits))
            
        
def get_score_by_max_retrace(retrace_percent):
    if(retrace_percent<=10):
        return 100-2*retrace_percent
    
    if(retrace_percent<20):
        return 80-2*(retrace_percent-10)
    
    if(retrace_percent<30):
        return 60-3*(retrace_percent-20)
    
    if(retrace_percent<40):
        return 30-3*(retrace_percent-30)
        
    if(retrace_percent<50):
        return 0-5*(retrace_percent-40)
    
    if(retrace_percent<60):
        return -50-5*(retrace_percent-50)
    
    return -100

# %%
vol_columns = []
for i in range(0,20):
    vol_columns += ['v_f_' + str(i)]

section_columns = ['symbol','up_X','down_X','ampl','incre','periods','ma',
                   'pre_start','pre_end','outburst',
                   'pre_ampl','pre_incre','pre_periods',
                   'pre_ma'] + vol_columns
print( 'section_columns '+ str(len(section_columns))+'\n'+ str(section_columns))

class Eagle:
    file_name = ''
    start_date = ''
    end_date = ''
    short = 30
    mid = 60


    def __init__(self,file_name, short,mid):
        self.file_name = file_name
        self.short = short
        self.mid = mid
        
        self.data = get_day_level_k(file_name);
        
        self.start_date = self.data['date'][:1].values[0]
        self.end_date = self.data['date'][-1:].values[0]
        
        self.section_df = pd.DataFrame(columns=section_columns)
        
    
    def next_periods_series(self,cur_date, latest_n):
        print('next_periods_series ' + cur_date)
        cur_index = self.data[self.data['date']==cur_date].index.values[0]
        end_index = cur_index.astype(int)+latest_n

        latest_part = self.data[cur_index:end_index]
        return latest_part

    
    

    def is_buy_point(self,cur_date):
        latest_n=3
        up_crossed = self.latest_n_period_up_crossed(cur_date, latest_n)
        keep_up = self.k_on_ma(cur_date, self.short)

        if(up_crossed == True and keep_up == True):
            if(debug):
                print(cur_date+' up cross and keep 3 k lines up on MA('+ str(short)+')')
            return True
        else:
            return False

    def is_sell_point(self,cur_date):
        down_cross = self.is_down_cross(cur_date)

        latest_n = 3
        latest_n_break_ma = self.latest_n_k_break_ma(cur_date, latest_n)

        deep_percent=3
        deep_break_ma = self.deep_k_break_ma(cur_date,deep_percent)

        if(down_cross == True):
            if(debug):
                print('down_cross')
            return True

        if(latest_n_break_ma == True):
            if(debug):
                print('latest_'+str(latest_n)+'_break_ma_'+str(mid))
            return True

        if(deep_break_ma == True):
            if(debug):
                print('deep_'+str(deep_percent)+'%_break_ma_'+str(mid))
            return True

        return False
    
    
    def is_stop_loss(self,cur_date,last_buy_date,last_buy_price):
        price = self.data[self.data['date']==cur_date]['close'].values[0]

        loss_percent = get_fix_stop_loss_percent()
        stop_loss_price=last_buy_price*(1-loss_percent/100)
        if(price<stop_loss_price):
            return True
        else:
            return False


    # max_profit_rate % 0.6
    def is_stop_profit_v1(self,floating_profits,taking=40):
        if(len(floating_profits)<1):
            return False

        max_profit = max(floating_profits)
        last_one = floating_profits[-1]

        taking_from_max = max_profit*(1-taking/100)
        if(max_profit>10 and last_one<taking_from_max):
            return True
        else:
            return False


    def is_stop_profit(self,floating_profits,taking=40):
        return self.is_stop_profit_v1(floating_profits)



    def send_go_signal(self,outburst, pre_amplitude, pre_ma_per, amplitude_threshold=60):
        if((outburst==True) and (pre_ma_per>-10)):
            return 'Buy'

        return 'Hold'
    
    def get_vol_features(self,cur_date):
        vol = self.get_vol(cur_date)
        
        vol_features = []
        for long in [10,20,40,60]:
            vol_features.append(int(vol/self.ma_vol(cur_date,long)))
            for short in [2,4,8,16]:
                temp_feature = int(self.ma_vol(cur_date,short)/self.ma_vol(cur_date,long))
                vol_features.append(temp_feature)

        return vol_features

# %%
class Account:
    init_money = 0
    start_date = ''
    account_money = 0
    account_shares = 0
    last_buy_price = 0
    last_buy_date = ''
    floating_profits = []
    operation_detail= pd.DataFrame(columns=['date','profit_rate','account_money'])
    daily_log=True
    
    def __init__(self,init_money,start_date,short,mid):
        self.init_money = init_money
        self.account_money = init_money
        self.start_date = start_date
        self.short = short
        self.mid = mid
        
        self.account_shares = 0
        self.last_buy_price = 0
        self.last_buy_date = ''
        self.floating_profits = []
        
        self.i = 0
        self.operation_detail = pd.DataFrame(columns=['date','profit_rate','account_money'])
        self.operation_detail.loc[self.i] = [start_date,0,self.init_money]
        self.i +=1
        
        self.daily_log=True
        
    
    def open_opsition(self,date,price):
        buy_shares = buy_how_many(self.account_money,price)
            
        if(self.daily_log==True):
            if(debug):
                print(date+' BUY price:'+ tostr(price) + ' shares:'+tostr(buy_shares)+ ' space:'+tostr(buy_shares*price*100/self.account_money))

        self.account_shares += buy_shares
        self.account_money -= buy_shares*price
        self.last_buy_price = price
        self.last_buy_date = date
        
    def sell_all(self,date, price, sell_type='sell_point'):
        sell_shares = sell_how_many(self.account_shares)
            
        self.account_shares -= sell_shares
        self.account_money += sell_shares*price
        
        profit_rate = (price-self.last_buy_price)*100/self.last_buy_price
        if(self.daily_log==True):
            if(debug):
                print(date +' '+sell_type+' ' +tostr(sell_shares)+' shares, profit rate:'+tostr(profit_rate)+'%')
                print('floating_profits:'+str(self.floating_profits))
                print()
            
        self.operation_detail.loc[self.i] = [date,profit_rate,self.account_money]
        self.i +=1
        self.floating_profits.clear()
            
    def daily_check(self,date,price):
        if(is_buy_point(date,self.short,self.mid)):
            if(self.account_shares==0):
                self.open_opsition(date,price)
                
        if(self.account_shares>0):
            floating_profit_percent = (price-self.last_buy_price)*100/self.last_buy_price
            self.floating_profits.append(round(floating_profit_percent,2))
            
#             if(is_stop_profit(self.floating_profits)):
#                 self.sell_all(date,price,'stop_profit')
            
            if(is_sell_point(date,self.short,self.mid)):
                self.sell_all(date,price,'sell_point')
                
            if(is_stop_loss(date,self.last_buy_date,self.last_buy_price)):
                self.sell_all(date,price,'stop_loss')
    
    def max_retrace(self):
        max_retrace_loss = 0
        
        moneys = self.operation_detail['account_money']
        for i in range(1,len(moneys)):
            history_part = moneys[:i+1]
            max_money = max(history_part)
            
            if(moneys[i]<max_money):
                retrace_percent = (max_money-moneys[i])*100/max_money
                
                if(retrace_percent>max_retrace_loss):
                    max_retrace_loss = retrace_percent

        return max_retrace_loss

    
    def continue_loss(self):
        max_loss_count = 0
        
        profits = self.operation_detail['profit_rate']
        for i in range(1,len(profits)):
            cur_profit = profits[i]
            
            if(cur_profit<=0):
                loss_count = 0
                j=i;
                while(j>=0 and profits[j]<=0):
                    loss_count+=1
                    j -= 1
                if(loss_count>max_loss_count):
                    max_loss_count = loss_count
                
        return max_loss_count
        
    def get_last_year_remain_money(self, year, the_first_year):
        if(year==the_first_year):
            return self.init_money
        
        last_year = year-1
        last_year_operations = self.operation_detail[self.operation_detail['year']==last_year]
        
        if(last_year_operations.shape[0]>0):
            return last_year_operations.loc[last_year_operations.shape[0]-1:]['account_money'].values[-1]
        else:
            return self.get_last_year_remain_money(last_year, the_first_year)
    
    def profit_per_year_period(self):
        self.operation_detail['year'] = self.operation_detail['date'].apply(lambda x: int(x.split('-')[0]))

        years_list = list(set(self.operation_detail['year'].values))
        
        years_list.sort()
        the_first_year = years_list[0]
        
        period_rates = []
        for i in range(0, len(years_list)):
            year = years_list[i]

            part = self.operation_detail[self.operation_detail['year']==year]
            remain_money = part.loc[part.shape[0]-1:]['account_money'].values[-1]
            
            last_year_remain_money = self.get_last_year_remain_money(year,the_first_year)
            
            growth_rate = (remain_money-last_year_remain_money)*100/last_year_remain_money
            period_rates.append(growth_rate)

        return period_rates
        
    
    def report(self):
        total_profit_per = (self.account_money-self.init_money)*100.0/self.init_money
        
        win_count = self.operation_detail[self.operation_detail['profit_rate']>0].shape[0]
        deal_count = self.operation_detail.shape[0]
        
        win_rate = win_count*100/deal_count
        continue_loss_times = self.continue_loss()
        max_retrace = self.max_retrace()
        
        period_rates = self.profit_per_year_period()
        period_profit_score = get_score_by_year_period_profits(period_rates)
        
        retrace_score = get_score_by_max_retrace(max_retrace)
        
        report_list = [self.short,self.mid,total_profit_per,
                       win_rate,continue_loss_times,max_retrace,
                       deal_count,win_count,
                       period_profit_score,retrace_score]
        
        return report_list

# %%
report_columns = ['ma_short','ma_mid','total_profit',
                  'win_rate','loss_times','max_retrace',
                  'deal_count','win_count',
                  'period_score','retrace_score']

def buy_and_sell(start_date,end_date,report_summary, short,mid):
    print('start go through MA(' + str(short) + ',' + str(mid) + ')')
    all_dates = data['date'][mid:]
    
    account = Account(initial_money,start_date,short,mid)
    
    start_year_s, start_mon_s, start_day_s = start_date.split('-')
    start_datetime = datetime(int(start_year_s), int(start_mon_s), int(start_day_s))

    end_year_s, end_mon_s, end_day_s = end_date.split('-')
    end_datetime = datetime(int(end_year_s), int(end_mon_s), int(end_day_s))
    
    for date in all_dates:
        if(not(out_of_range(date,start_datetime,end_datetime))):
            price = data[data['date']==date]['close'].values[0]
            account.daily_check(date,price)
   
    report_data = account.report()
    report_summary.loc[report_summary.shape[0]+1] = report_data

    return report_summary

# %%
def test():
    initial_money=100000

    report_summary = pd.DataFrame(columns=report_columns)
    summary = buy_and_sell('2007-07-05','2010-10-18',report_summary, short=10, mid=50)
    print(summary)
    print('Done')

    
# test()

# %%
def grid_search_ma():
    shorts = range(5,40,10)
    mids = range(10,80,10)
    
    initial_money=100000
    report_summary = pd.DataFrame(columns=report_columns)
    
    for short_item in shorts:
        for mid_item in mids:
            if(mid_item>short_item):
                summary = buy_and_sell('2011-06-02','2019-02-15', report_summary, short_item, mid_item)
                print('done search MA(' + str(short_item) + ',' + str(mid_item) + ')')

    return report_summary

# summary = grid_search_ma()
# summary.sort_values(by=['total_profit','retrace_score','period_score'], ascending=False)
