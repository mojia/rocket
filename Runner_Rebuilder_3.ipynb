# %%
# %run BasicDataRebuilder.ipynb


rebuild = BasicDataRebuilder()
rebuild.rebuild_all_sections(300,400,30,60)
# Out:
# rebuild_all_sections get 100 symbols
# build SZ#000037 sections
# start to analyse Day level SZ#000037 all cross sections...
# build SZ#000691 sections
# start to analyse Day level SZ#000691 all cross sections...
# 2.0 build SZ#000998 sections
# start to analyse Day level SZ#000998 all cross sections...
# build SZ#002207 sections
# start to analyse Day level SZ#002207 all cross sections...
# 4.0 build SZ#002421 sections
# start to analyse Day level SZ#002421 all cross sections...
# build SZ#002635 sections
# start to analyse Day level SZ#002635 all cross sections...
# 6.0 build SZ#002861 sections
# start to analyse Day level SZ#002861 all cross sections...
# build SZ#300139 sections
# start to analyse Day level SZ#300139 all cross sections...
# 8.0 build SZ#300353 sections
# start to analyse Day level SZ#300353 all cross sections...
# build SZ#300571 sections
# start to analyse Day level SZ#300571 all cross sections...
# 10.0 build SZ#000038 sections
# start to analyse Day level SZ#000038 all cross sections...
# build SZ#000692 sections
# start to analyse Day level SZ#000692 all cross sections...
# 12.0 build SZ#000999 sections
# start to analyse Day level SZ#000999 all cross sections...
# build SZ#002208 sections
# start to analyse Day level SZ#002208 all cross sections...
# 14.0 build SZ#002422 sections
# start to analyse Day level SZ#002422 all cross sections...
# build SZ#002636 sections
# start to analyse Day level SZ#002636 all cross sections...
# 16.0 build SZ#002862 sections
# start to analyse Day level SZ#002862 all cross sections...
# build SZ#300140 sections
# start to analyse Day level SZ#300140 all cross sections...
# 18.0 build SZ#300354 sections
# start to analyse Day level SZ#300354 all cross sections...
# build SZ#300572 sections
# start to analyse Day level SZ#300572 all cross sections...
# 20.0 build SZ#000039 sections
# start to analyse Day level SZ#000039 all cross sections...
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:52: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:74: RuntimeWarning: divide by zero encountered in double_scalars
# build SZ#000693 sections
# start to analyse Day level SZ#000693 all cross sections...
# 22.0 build SZ#001696 sections
# start to analyse Day level SZ#001696 all cross sections...
# build SZ#002209 sections
# start to analyse Day level SZ#002209 all cross sections...
# 24.0 build SZ#002423 sections
# start to analyse Day level SZ#002423 all cross sections...
# build SZ#002637 sections
# start to analyse Day level SZ#002637 all cross sections...
# 26.0 build SZ#002863 sections
# start to analyse Day level SZ#002863 all cross sections...
# build SZ#300141 sections
# start to analyse Day level SZ#300141 all cross sections...
# 28.0 build SZ#300355 sections
# start to analyse Day level SZ#300355 all cross sections...
# build SZ#300573 sections
# start to analyse Day level SZ#300573 all cross sections...
# 30.0 build SZ#000040 sections
# start to analyse Day level SZ#000040 all cross sections...
# build SZ#000695 sections
# start to analyse Day level SZ#000695 all cross sections...
# 32.0 build SZ#001872 sections
# start to analyse Day level SZ#001872 all cross sections...
# build SZ#002210 sections
# start to analyse Day level SZ#002210 all cross sections...
# 34.0 build SZ#002424 sections
# start to analyse Day level SZ#002424 all cross sections...
# build SZ#002638 sections
# start to analyse Day level SZ#002638 all cross sections...
# 36.0 build SZ#002864 sections
# start to analyse Day level SZ#002864 all cross sections...
# build SZ#300142 sections
# start to analyse Day level SZ#300142 all cross sections...
# 38.0 build SZ#300356 sections
# start to analyse Day level SZ#300356 all cross sections...
# build SZ#300575 sections
# start to analyse Day level SZ#300575 all cross sections...
# 40.0 build SZ#000042 sections
# start to analyse Day level SZ#000042 all cross sections...
# build SZ#000697 sections
# start to analyse Day level SZ#000697 all cross sections...
# 42.0 build SZ#001896 sections
# start to analyse Day level SZ#001896 all cross sections...
# build SZ#002211 sections
# start to analyse Day level SZ#002211 all cross sections...
# 44.0 build SZ#002425 sections
# start to analyse Day level SZ#002425 all cross sections...
# build SZ#002639 sections
# start to analyse Day level SZ#002639 all cross sections...
# 46.0 build SZ#002865 sections
# start to analyse Day level SZ#002865 all cross sections...
# build SZ#300143 sections
# start to analyse Day level SZ#300143 all cross sections...
# 48.0 build SZ#300357 sections
# start to analyse Day level SZ#300357 all cross sections...
# build SZ#300576 sections
# start to analyse Day level SZ#300576 all cross sections...
# 50.0 build SZ#000043 sections
# start to analyse Day level SZ#000043 all cross sections...
# build SZ#000698 sections
# start to analyse Day level SZ#000698 all cross sections...
# 52.0 build SZ#001965 sections
# start to analyse Day level SZ#001965 all cross sections...
# build SZ#002212 sections
# start to analyse Day level SZ#002212 all cross sections...
# 54.0 build SZ#002426 sections
# start to analyse Day level SZ#002426 all cross sections...
# build SZ#002640 sections
# start to analyse Day level SZ#002640 all cross sections...
# 56.0 build SZ#002866 sections
# start to analyse Day level SZ#002866 all cross sections...
# build SZ#300144 sections
# start to analyse Day level SZ#300144 all cross sections...
# 58.0 build SZ#300358 sections
# start to analyse Day level SZ#300358 all cross sections...
# build SZ#300577 sections
# start to analyse Day level SZ#300577 all cross sections...
# 60.0 build SZ#000045 sections
# start to analyse Day level SZ#000045 all cross sections...
# build SZ#000700 sections
# start to analyse Day level SZ#000700 all cross sections...
# 62.0 build SZ#001979 sections
# start to analyse Day level SZ#001979 all cross sections...
# build SZ#002213 sections
# start to analyse Day level SZ#002213 all cross sections...
# 64.0 build SZ#002427 sections
# start to analyse Day level SZ#002427 all cross sections...
# build SZ#002641 sections
# start to analyse Day level SZ#002641 all cross sections...
# 66.0 build SZ#002867 sections
# start to analyse Day level SZ#002867 all cross sections...
# build SZ#300145 sections
# start to analyse Day level SZ#300145 all cross sections...
# 68.0 build SZ#300359 sections
# start to analyse Day level SZ#300359 all cross sections...
# build SZ#300578 sections
# start to analyse Day level SZ#300578 all cross sections...
# 70.0 build SZ#000046 sections
# start to analyse Day level SZ#000046 all cross sections...
# build SZ#000701 sections
# start to analyse Day level SZ#000701 all cross sections...
# 72.0 build SZ#002001 sections
# start to analyse Day level SZ#002001 all cross sections...
# build SZ#002214 sections
# start to analyse Day level SZ#002214 all cross sections...
# 74.0 build SZ#002428 sections
# start to analyse Day level SZ#002428 all cross sections...
# build SZ#002642 sections
# start to analyse Day level SZ#002642 all cross sections...
# 76.0 build SZ#002868 sections
# start to analyse Day level SZ#002868 all cross sections...
# build SZ#300146 sections
# start to analyse Day level SZ#300146 all cross sections...
# 78.0 build SZ#300360 sections
# start to analyse Day level SZ#300360 all cross sections...
# build SZ#300579 sections
# start to analyse Day level SZ#300579 all cross sections...
# 80.0 build SZ#000048 sections
# start to analyse Day level SZ#000048 all cross sections...
# build SZ#000702 sections
# start to analyse Day level SZ#000702 all cross sections...
# 82.0 build SZ#002002 sections
# start to analyse Day level SZ#002002 all cross sections...
# build SZ#002215 sections
# start to analyse Day level SZ#002215 all cross sections...
# 84.0 build SZ#002429 sections
# start to analyse Day level SZ#002429 all cross sections...
# build SZ#002643 sections
# start to analyse Day level SZ#002643 all cross sections...
# 86.0 build SZ#002869 sections
# start to analyse Day level SZ#002869 all cross sections...
# build SZ#300147 sections
# start to analyse Day level SZ#300147 all cross sections...
# 88.0 build SZ#300362 sections
# start to analyse Day level SZ#300362 all cross sections...
# build SZ#300580 sections
# start to analyse Day level SZ#300580 all cross sections...
# 90.0 build SZ#000049 sections
# start to analyse Day level SZ#000049 all cross sections...
# build SZ#000703 sections
# start to analyse Day level SZ#000703 all cross sections...
# 92.0 build SZ#002003 sections
# start to analyse Day level SZ#002003 all cross sections...
# build SZ#002216 sections
# start to analyse Day level SZ#002216 all cross sections...
# 94.0 build SZ#002430 sections
# start to analyse Day level SZ#002430 all cross sections...
# build SZ#002644 sections
# start to analyse Day level SZ#002644 all cross sections...
# 96.0 build SZ#002870 sections
# start to analyse Day level SZ#002870 all cross sections...
# build SZ#300148 sections
# start to analyse Day level SZ#300148 all cross sections...
# 98.0 build SZ#300363 sections
# start to analyse Day level SZ#300363 all cross sections...
# build SZ#300581 sections
# start to analyse Day level SZ#300581 all cross sections...
# 100.0

# %%
# %run BasicDataRebuilder.ipynb


rebuild = BasicDataRebuilder()
rebuild.rebuild_chan_data(30,50,30,60)
# Out:
# rebuild chan data get 20 symbols
# 10.0
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:227: RuntimeWarning: divide by zero encountered in double_scalars
# 20.0 30.0 40.0 50.0 60.0 70.0 80.0 90.0 100.0
