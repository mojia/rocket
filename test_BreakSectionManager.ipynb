# %%
# %run BreakSectionManager.ipynb

symbol = 'SZ#002161'
sectionManager = BreakSectionManager(symbol, level_day, 5, 10)
sections = sectionManager.analyse_all_break_sections()
sections
# Out:
# start to analyse Day level SZ#002161 all break sections...
# 2007-11-21 highest_price 3.87 cur_price:4.0
# 2007-11-27 lowest_price 3.41 cur_price:3.39
# 2007-11-21 section ['SZ#002161', '2007-11-21', '2007-11-27', 4.0, 3.39]
# end_date 2007-11-27
# 2007-12-11 highest_price 3.63 cur_price:3.67
# 2008-01-17 lowest_price 4.41 cur_price:4.37
# 2007-12-11 section ['SZ#002161', '2007-12-11', '2008-01-17', 3.67, 4.37]
# end_date 2008-01-17
# 2008-02-15 highest_price 5.12 cur_price:5.15
# 2008-02-25 lowest_price 5.17 cur_price:5.07
# 2008-02-15 section ['SZ#002161', '2008-02-15', '2008-02-25', 5.15, 5.07]
# end_date 2008-02-25
# 2008-03-04 highest_price 5.44 cur_price:5.49
# 2008-03-18 lowest_price 5.25 cur_price:4.97
# 2008-03-04 section ['SZ#002161', '2008-03-04', '2008-03-18', 5.49, 4.97]
# end_date 2008-03-18
# 2008-03-24 highest_price 6.13 cur_price:6.24
# 2008-04-01 lowest_price 5.92 cur_price:5.78
# 2008-03-24 section ['SZ#002161', '2008-03-24', '2008-04-01', 6.24, 5.78]
# ...
