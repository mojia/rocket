# D_SZ#000713.txt level:Week data.shape:(929, 8)
# start to analyse Week level SZ#000713 all cross sections...
# 57.54% end to analyse Week level SZ#000713 all cross sections...
# ------------------------- 0.8130081300813008% ---------------------------
# D_SZ#002065.txt level:Week data.shape:(571, 8)
# start to analyse Week level SZ#002065 all cross sections...
# 97.85% end to analyse Week level SZ#002065 all cross sections...
# ------------------------- 1.6260162601626016% ---------------------------
# D_SZ#002333.txt level:Week data.shape:(463, 8)
# ------------------------- 2.4390243902439024% ---------------------------
# D_SZ#002601.txt level:Week data.shape:(370, 8)
# start to analyse Week level SZ#002601 all cross sections...
# end to analyse Week level SZ#002601 all cross sections...
# ------------------------- 3.252032520325203% ---------------------------
# D_SZ#002882.txt level:Week data.shape:(81, 8)
# start to analyse Week level SZ#002882 all cross sections...
# ...

# %%
day_sections_df = sectionAnalyser.get_all_sections_of_all_symbols(level_day)
sectionAnalyser.get_price_incre_percent_report(day_sections_df)
# Out:
# D_SZ#000713.txt level:Day data.shape:(4415, 10)
# start to analyse Day level SZ#000713 all cross sections...
# 11.48% 22.96% 34.44% 45.92% 57.41% 68.89% 80.37% 91.85% end to analyse Day level SZ#000713 all cross sections...
# ------------------------- 0.8130081300813008% ---------------------------
# D_SZ#002065.txt level:Day data.shape:(2664, 10)
# start to analyse Day level SZ#002065 all cross sections...
# 19.20% 38.40% 57.60% 76.80% 96.01% end to analyse Day level SZ#002065 all cross sections...
# ------------------------- 1.6260162601626016% ---------------------------
# D_SZ#002333.txt level:Day data.shape:(2176, 10)
# start to analyse Day level SZ#002333 all cross sections...
# 23.63% 47.26% 70.89% 94.52% end to analyse Day level SZ#002333 all cross sections...
# ------------------------- 2.4390243902439024% ---------------------------
# D_SZ#002601.txt level:Day data.shape:(1739, 10)
# start to analyse Day level SZ#002601 all cross sections...
# ...

# %%
for threshold in [10,20,40,60,80]:
            over_count = day_sections_df[day_sections_df['price_incre_per'] > threshold].shape[0]
            total = day_sections_df.shape[0]

            if(total>0):
                rate = 100*over_count/total
                print('threshold '+ str(threshold) + ', over count size:'+ str(over_count) +
                      ' total size:'+str(total) + ' rate ' +str(rate))
# Out:
# threshold 10, over count size:419 total size:2073 rate 20.21225277375784
# threshold 20, over count size:286 total size:2073 rate 13.796430294259528
# threshold 40, over count size:178 total size:2073 rate 8.586589483839846
# threshold 60, over count size:119 total size:2073 rate 5.740472744814279
# threshold 80, over count size:93 total size:2073 rate 4.486251808972503

# %%
up_sections_df = day_sections_df[day_sections_df['ma_mid_direction']=='Up']

for threshold in [10,20,40,60,80]:
            over_count = up_sections_df[up_sections_df['price_incre_per'] > threshold].shape[0]
            total = up_sections_df.shape[0]

            if(total>0):
                rate = 100*over_count/total
                print('threshold '+ str(threshold) + ', over count size:'+ str(over_count) +
                      ' total size:'+str(total) + ' rate ' +str(rate))
# Out:
# threshold 10, over count size:217 total size:853 rate 25.439624853458383
# threshold 20, over count size:163 total size:853 rate 19.10902696365768
# threshold 40, over count size:101 total size:853 rate 11.840562719812427
# threshold 60, over count size:75 total size:853 rate 8.792497069167643
# threshold 80, over count size:60 total size:853 rate 7.033997655334115

# %%
boll_sections_df = day_sections_df[day_sections_df['boll']==True]

for threshold in [10,20,40,60,80]:
            over_count = boll_sections_df[boll_sections_df['price_incre_per'] > threshold].shape[0]
            total = boll_sections_df.shape[0]

            if(total>0):
                rate = 100*over_count/total
                print('threshold '+ str(threshold) + ', over count size:'+ str(over_count) +
                      ' total size:'+str(total) + ' rate ' +str(rate))
# Out:
# threshold 10, over count size:354 total size:1528 rate 23.167539267015705
# threshold 20, over count size:246 total size:1528 rate 16.099476439790575
# threshold 40, over count size:155 total size:1528 rate 10.143979057591624
# threshold 60, over count size:104 total size:1528 rate 6.806282722513089
# threshold 80, over count size:81 total size:1528 rate 5.301047120418848

# %%
boll_ma_up_sections_df = day_sections_df[(day_sections_df['boll']==True) & (day_sections_df['ma_mid_direction']=='Up')]

for threshold in [10,20,40,60,80]:
            over_count = boll_ma_up_sections_df[boll_ma_up_sections_df['price_incre_per'] > threshold].shape[0]
            total = boll_ma_up_sections_df.shape[0]

            if(total>0):
                rate = 100*over_count/total
                print('threshold '+ str(threshold) + ', over count size:'+ str(over_count) +
                      ' total size:'+str(total) + ' rate ' +str(rate))
# Out:
# threshold 10, over count size:207 total size:775 rate 26.70967741935484
# threshold 20, over count size:155 total size:775 rate 20.0
# threshold 40, over count size:96 total size:775 rate 12.387096774193548
# threshold 60, over count size:72 total size:775 rate 9.290322580645162
# threshold 80, over count size:57 total size:775 rate 7.354838709677419

# %%
resonate_df = sectionAnalyser.get_cross_resonate_on_week_and_day()
resonate_df
# Out:
# D_SZ#000713.txt level:Week data.shape:(929, 8)
# ------------------------- 0.8130081300813008% ---------------------------
# D_SZ#002065.txt level:Week data.shape:(571, 8)
# ------------------------- 1.6260162601626016% ---------------------------
# D_SZ#002333.txt level:Week data.shape:(463, 8)
# ------------------------- 2.4390243902439024% ---------------------------
# D_SZ#002601.txt level:Week data.shape:(370, 8)
# ------------------------- 3.252032520325203% ---------------------------
# D_SZ#002882.txt level:Week data.shape:(81, 8)
# ------------------------- 4.065040650406504% ---------------------------
# D_SZ#300207.txt level:Week data.shape:(392, 8)
# ------------------------- 4.878048780487805% ---------------------------
# D_SZ#300476.txt level:Week data.shape:(189, 8)
# ------------------------- 5.691056910569106% ---------------------------
# D_SZ#000715.txt level:Week data.shape:(898, 8)
# ------------------------- 6.504065040650406% ---------------------------
# ...

# %%
def report(df):
    avg_percent = df['d_price_incre'].mean()
    print('avg_percent:' + str(avg_percent))
    for threshold in [10,20,40,60,80]:
        over_count = df[df['d_price_incre'] > threshold].shape[0]
        total = df.shape[0]

        if(total>0):
            rate = 100*over_count/total
            print('threshold '+ str(threshold) + ', over count size:'+ str(over_count) +
                  ' total size:'+str(total) + ' rate ' +str(rate))    

                    
report(resonate_df[(resonate_df['d_ma_short_dire']=='Up') & (resonate_df['d_ma_mid_dire']=='Up')])
# Out:
# avg_percent:21.747664670658683
# threshold 10, over count size:110 total size:334 rate 32.93413173652694
# threshold 20, over count size:83 total size:334 rate 24.850299401197606
# threshold 40, over count size:47 total size:334 rate 14.071856287425149
# threshold 60, over count size:34 total size:334 rate 10.179640718562874
# threshold 80, over count size:26 total size:334 rate 7.7844311377245505

# %%
d_boll_up_resonate_df = resonate_df[(resonate_df['d_boll']==True) & (resonate_df['d_ma_short_dire']=='Up')]

for threshold in [10,20,40,60,80]:
            over_count = d_boll_up_resonate_df[d_boll_up_resonate_df['d_price_incre'] > threshold].shape[0]
            total = d_boll_up_resonate_df.shape[0]

            if(total>0):
                rate = 100*over_count/total
                print('threshold '+ str(threshold) + ', over count size:'+ str(over_count) +
                      ' total size:'+str(total) + ' rate ' +str(rate))
# Out:
# threshold 10, over count size:180 total size:564 rate 31.914893617021278
# threshold 20, over count size:130 total size:564 rate 23.04964539007092
# threshold 40, over count size:77 total size:564 rate 13.652482269503546
# threshold 60, over count size:49 total size:564 rate 8.687943262411348
# threshold 80, over count size:35 total size:564 rate 6.205673758865248
