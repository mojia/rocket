# %%
import pandas as pd
import numpy as np

# %run Util.ipynb
# %run Section.ipynb
# %run Constant.ipynb

class SectionManager:
    section_df = pd.DataFrame(columns=section_columns)
    day_k = pd.DataFrame()
    week_k = pd.DataFrame()

    def __init__(self, day_file_name, level, short, mid):
        self.day_file_name = day_file_name
        if(self.day_file_name.find('_')==-1):
            self.symbol = self.day_file_name
        else:
            self.symbol = self.day_file_name.split('_')[1].replace('.txt','')
        
        self.level = level
        self.short = short
        self.mid = mid
        
        if(self.level==level_day):
            self.day_k = get_day_K(self.symbol)
            self.data = self.day_k
        elif(self.level==level_week):
            self.week_k = get_week_K(self.symbol)
            self.data = self.week_k
            
        self.start_date = self.data['date'][:1].values[0]
        self.end_date = self.data['date'][-1:].values[0]
        
        self.section_df = pd.DataFrame(columns=section_columns)
        self.section = Section(self.day_k, self.week_k, self.level, self.short, self.mid)
           
    
    def build_file_path(self):
        original_name = self.symbol
        return  original_section_dir + self.level + '/' + self.level+'_' 'sections_'+section_version+'_'+ original_name +'.txt'
    
            
    def get_all_cross_sections(self):
        file_path = self.build_file_path()
        
        if(os.path.exists(file_path)):
            self.section_df = pd.read_csv(file_path)
            
            self.section_df['s_datetime'] = pd.to_datetime(self.section_df['s_datetime'])
            self.section_df['e_datetime'] = pd.to_datetime(self.section_df['e_datetime'])
        else:
            self.analyse_all_cross_sections()
                    
            file_path = self.build_file_path()
            self.section_df.to_csv(file_path, index=0)

        return self.section_df
        

    def find_sections_between(self, start_date, end_date):
        if(self.section_df.shape[0]==0):
            self.section_df = self.get_all_cross_sections()
            
        start_datetime = to_datetime(start_date)
        end_datetime = to_datetime(end_date)

        part = self.section_df[(self.section_df['s_datetime']>=start_datetime) & (self.section_df['s_datetime']<=end_datetime)]

        return part

    
#     -------------------------- Private Functions -------------------------------------
            
    def analyse_cross_for_one_specific_day(self,cur_date):
        metric = Metric(self.day_k, self.week_k, self.level, self.short, self.mid)
        
        if(metric.is_up_cross(cur_date)):
            start = cur_date
            next_sections = self.section.get_section(start, self.end_date)
            previous_sections = self.section.get_section(self.start_date, start)

            next_down_cross_date = metric.next_down_cross(next_sections)
            next_k_down_mid_ma_date = metric.next_down_ma(self.mid, next_sections)
            
            if(next_down_cross_date == 'None'):
                return 

            amplitude = self.section.get_amplitude_percent(start,next_down_cross_date)
            ma_percent = self.section.get_ma_increase_per(start,next_down_cross_date)

            price_percent = self.section.get_price_increase_per(start,next_down_cross_date)
            break_mid_ma_price_incre_percent = self.section.get_price_increase_per(start,next_k_down_mid_ma_date)
            
            periods = self.section.how_many_periods(start,next_down_cross_date)
            boll = metric.is_on_boll(cur_date)
            
            ma_short_direction = metric.ma_direction(cur_date, self.short)
            ma_mid_direction = metric.ma_direction(cur_date, self.mid)
            
            return [self.symbol,start,next_down_cross_date,amplitude,ma_percent,
                    periods,boll,price_percent,ma_short_direction,ma_mid_direction,
                   break_mid_ma_price_incre_percent]
    
        
#   找到该股所有的金叉，死叉波段
    def analyse_all_cross_sections(self):
        print('start to analyse '+self.level+' level '+ self.symbol+' all cross sections...')
        all_dates = self.data['date'][self.mid:]
       
        start_datetime = to_datetime(self.start_date)
        end_datetime = to_datetime(self.end_date)

        progress = 0
        for date in all_dates:
            if(not(out_of_range(date,start_datetime,end_datetime))):
                one_section = self.analyse_cross_for_one_specific_day(date)
                
                if(not(one_section is None) and (len(one_section)>0)):
                    self.section_df.loc[self.section_df.shape[0] +1] = one_section

            progress += 1
            if(progress % 500 == 0):
                print(tostr(progress*100/len(all_dates)) + '%', end=' ')
                
        print('end to analyse '+self.level+' level '+ self.symbol+' all cross sections...')
        
        self.section_df['s_datetime'] = pd.to_datetime(self.section_df['s_date'])
        self.section_df['e_datetime'] = pd.to_datetime(self.section_df['e_date'])

        return self.section_df
