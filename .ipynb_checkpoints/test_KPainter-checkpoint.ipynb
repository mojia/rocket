# %%
# %run KPainter.ipynb

symbol = 'SZ#000001'
start_date = '2016-07-08'  
end_date = '2016-10-18'
short=30
mid=60

painter = KPainter(symbol,level_day,short,mid)
painter.draw_single_level_chan_bi(start_date,end_date,8.45,8.80)
