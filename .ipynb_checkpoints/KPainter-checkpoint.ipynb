# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.tools.plotting import scatter_matrix

mpl.style.use('ggplot')
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
plt.rc('figure', figsize=(14, 10))#设置图片大小
sns.set_style('white')

# %matplotlib inline
# %run Metric.ipynb
# %run Util.ipynb
# %run ChanBiAnalyser.ipynb


class KPainter:
    
    def __init__(self):
        self.arrow_props = dict(arrowstyle='->', connectionstyle="arc3,rad=.2")
    
    
    def get_xy_coord(self,chan_bi_df,key):
        return (chan_bi_df.loc[key,'datetime'], chan_bi_df.loc[key,'price'])
        
    
    def get_xytext_coord(self,row_series):
        if(row_series['turning_point']=='top'):
            return (-20, -20)
        else:
            return (10, 10)
        
    
    def draw_chan_bi(self,chan_bi_df):
        chan_bi_df['datetime'] = pd.to_datetime(chan_bi_df['date'])
        
        plt.rc('figure', figsize=(14, 10))
        plt.plot(chan_bi_df['datetime'],chan_bi_df['price'],'r-o',label='笔')
        
        for key,row in chan_bi_df.iterrows():
            increase_per = chan_bi_df.loc[key,'increase']
            
            xy_coord = self.get_xy_coord(chan_bi_df,key)
            xytext_coord = self.get_xytext_coord(row)
            
            plt.annotate(s=str(increase_per)+'%', xy=xy_coord, 
                         xycoords='data', xytext=xytext_coord,
                         textcoords='offset points', fontsize=14,
                         arrowprops=self.arrow_props)


chanBiAnalyser = ChanBiAnalyser('SZ#002871',level_day,'2018-07-25','2019-02-21',30,60)
chan_bi_df = chanBiAnalyser.confirm_chan_bi()

painter = KPainter()
painter.draw_chan_bi(chan_bi_df)
        
# chan_bi_df

# %%
metric = Metric('SZ#002871',level_day,30,60)



w_df = pd.DataFrame(columns=['date','price'])
w_df.loc[0] = ['2018-12-26',10]
w_df.loc[1] = ['2019-03-26',100]
w_df['datetime'] = pd.to_datetime(w_df['date'])



d_df = pd.DataFrame(columns=['date','price'])
d_df.loc[0] = ['2018-12-26',10]
d_df.loc[1] = ['2019-01-26',100]
d_df.loc[2] = ['2019-02-26',50]
d_df.loc[3] = ['2019-03-26',150]
d_df['datetime'] = pd.to_datetime(d_df['date'])


plt.plot(d_df['datetime'],d_df['price'],'r',label='笔')
plt.plot(w_df['datetime'],w_df['price'],'b',label='笔')
