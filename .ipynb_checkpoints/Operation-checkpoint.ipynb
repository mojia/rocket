# %%
import pandas as pd

# %run Metric.ipynb
# %run DataSource.ipynb
# %run Account.ipynb

Sell_type_stop_loss=1
Sell_type_ma_down_cross=2

class Operation:
    
    # symbol=SZ#002335
    def __init__(self, account, symbol, short, mid):
        self.account = account
        self.symbol = symbol
        self.short = short
        self.mid = mid
        
        self.operation_detail = pd.DataFrame(columns=operation_columns)
        
        self.metric = Metric(self.symbol, level_day, self.short, self.mid)
        self.dataSource = DataSource(self.symbol, level_day)
        self.data = self.dataSource.get_data()


    def get_fix_stop_loss_percent(self):
        return 7


    # 止损价格
    def get_stop_loss_price(self,price):
        if(price>0):
            return price * (1-self.get_fix_stop_loss_percent()/100)
        else:
            return price * (1+self.get_fix_stop_loss_percent()/100)


    #     单笔交易承担亏损3%
    def buy_how_many(self, account_money, price, risk_percent=3):
        risk_money = account_money*risk_percent/100

    #     止损价格
        stop_loss_price = self.get_stop_loss_price(price)
        plan_shares = risk_money/(price-stop_loss_price)
        
        if(plan_shares<=0):
            print('account_money:'+str(account_money) + ' price:'+str(price)+ ' plan_shares:'+str(plan_shares))

        return int((plan_shares)/100)*100

    def sell_how_many(self):
        return self.account.get_shares(self.symbol)
    
    def open_opsition(self,date,price):
        account_cash = self.account.get_all_cash()
        
        buy_shares = self.buy_how_many(account_cash,price)
        
        if(buy_shares>0):
            self.account.buy_stock(self.symbol,date,price,buy_shares)
        
        return buy_shares
        
        
    def sell_all(self,date, price, sell_type='sell_point'):
        sell_shares = self.sell_how_many()
            
        self.account.sell_stock(self.symbol,date,price,sell_shares)
        
        profit_rate = (price-self.account.get_last_time_buy_price(self.symbol))*100/self.account.get_last_time_buy_price(self.symbol)
        space = 0
        
        operation_log = [self.symbol,self.account.get_last_time_buy_date(self.symbol),date,
                        self.account.get_last_time_buy_price(self.symbol),price,
                        sell_shares,space,
                        profit_rate,self.account.get_all_cash()]
        self.operation_detail.loc[self.operation_detail.shape[0]+1] = operation_log
        
        
    def watching_for_sell(self,cur_date):
        future_d_k = self.metric.next_series(cur_date,100000)
        
        for index,row in future_d_k.iterrows():
            price = row['close']
            date = row['date']
            
            self.account.daily_audit(date)
            
            if(self.account.has_shares()==True):
                if(self.which_sell_type(date)>0):
                    sell_price = self.get_sell_price(date)
                    
                    self.sell_all(date, sell_price,'sell_point')
                    return date
            else:
                print('Warning!!! dirty data, '+self.symbol +' '+ date + ' has no shares, but bought.')

    
    def get_operations(self):
        return self.operation_detail
    
    def is_ma_cross_buy_point(self,cur_date):
        return self.metric.is_up_cross(cur_date)
    
    
    def is_ma_cross_sell_point(self,cur_date):
        return self.metric.is_down_cross(cur_date)
    
        
    def is_ma_cross_buy_point_delay_confirm(self,cur_date):
        latest_n=3
        up_crossed = self.latest_n_period_up_crossed(cur_date, latest_n)
        keep_up = self.k_on_ma(cur_date, self.short)

        if(up_crossed == True and keep_up == True):
            if(debug):
                print(cur_date+' up cross and keep 3 k lines up on MA('+ str(short)+')')
            return True
        else:
            return False
        
    def is_ma_cross_sell_point_delay_confirm(self, cur_date):
        down_cross = self.is_down_cross(cur_date)

        latest_n = 3
        latest_n_break_ma = self.latest_n_k_break_ma(cur_date, latest_n)

        deep_percent=3
        deep_break_ma = self.deep_k_break_ma(cur_date,deep_percent)

        if(down_cross == True):
            if(debug):
                print('down_cross')
            return True

        if(latest_n_break_ma == True):
            if(debug):
                print('latest_'+str(latest_n)+'_break_ma_'+str(mid))
            return True

        if(deep_break_ma == True):
            if(debug):
                print('deep_'+str(deep_percent)+'%_break_ma_'+str(mid))
            return True

        return False
    
        
    def is_buy_point(self,cur_date):
        return self.is_ma_cross_buy_point(cur_date)
        
        
    def which_sell_type(self,cur_date):
        if(self.is_over_stop_loss(cur_date)):
            return Sell_type_stop_loss
        
        ma_sell = self.is_ma_cross_sell_point(cur_date)
        if(ma_sell==True):
            return Sell_type_ma_down_cross
        else:
            return 0
    
    def get_sell_price(self,cur_date):
        close_price = self.data[self.data['date']==cur_date]['close'].values[0]
        
        sell_type = self.which_sell_type(cur_date)

        if(sell_type==Sell_type_ma_down_cross):
            return close_price
        
        if(sell_type==Sell_type_stop_loss):
            stop_price = self.get_over_stop_loss_price(cur_date)
            return stop_price
            
        print('Warning, Not go to the sell point!')
        return None
    
    def get_over_stop_loss_price(self, cur_date):
        price = self.data[self.data['date']==cur_date]['close'].values[0]

        loss_percent = self.get_fix_stop_loss_percent()
        
        last_buy_price = self.account.get_last_time_buy_price(self.symbol)
        if(last_buy_price>0):
            stop_loss_price=last_buy_price*(1-loss_percent/100)
        else:
            stop_loss_price=last_buy_price*(1+loss_percent/100)

        return stop_loss_price
    
    def is_over_stop_loss(self,cur_date):
        stop_loss_price = self.get_over_stop_loss_price(cur_date)
        price = self.data[self.data['date']==cur_date]['close'].values[0]
        
        if(price<stop_loss_price):
            return True
        else:
            return False


    def send_go_signal(self,outburst, pre_amplitude, pre_ma_per, amplitude_threshold=60):
        if((outburst==True) and (pre_ma_per>-10)):
            return 'Buy'

        return 'Hold'
    
    def get_vol_features(self,cur_date):
        vol = self.get_vol(cur_date)
        
        vol_features = []
        for long in [10,20,40,60]:
            vol_features.append(int(vol/self.ma_vol(cur_date,long)))
            for short in [2,4,8,16]:
                temp_feature = int(self.ma_vol(cur_date,short)/self.ma_vol(cur_date,long))
                vol_features.append(temp_feature)

        return vol_features
