# %%
# %run SectionManager.ipynb
# %run Constant.ipynb

print('Hello')

symbol='SZ#002022'

sm = SectionManager(symbol,level_day,30,60)

sm.build_file_path()
# Out:
# Hello
# '/Users/xinwang/stock/data/original_sections/Day/Day_30_60_sections_V0.8_SZ#002022.txt'

# %%
sm.get_all_cross_sections()
# Out:
# start to analyse Day level SZ#002022 all cross sections...
# 14.67% 29.33% 44.00% 58.67% 73.34% 88.00% end to analyse Day level SZ#002022 all cross sections...
#        symbol      s_date      e_date    ampl  ma_per periods   boll  \
# 1   SZ#002022  2004-12-22  2004-12-24   10.53   -3.28       3  False
# 2   SZ#002022  2005-03-18  2005-05-11   44.66   -1.33      33  False
# 3   SZ#002022  2005-07-19  2006-07-27  322.58  255.91     222  False
# 4   SZ#002022  2006-09-22  2007-12-04  773.24  722.73     288   True
# 5   SZ#002022  2007-12-28  2008-03-27   43.09   28.26      58   True
# 6   SZ#002022  2008-05-29  2008-07-04   31.39   -4.49      25  False
# 7   SZ#002022  2008-08-07  2008-08-29   32.62   -5.55      17  False
# 8   SZ#002022  2008-12-05  2009-03-04   29.81   19.94      57   True
# 9   SZ#002022  2009-05-08  2009-08-19   52.45    9.84      71  False
# 10  SZ#002022  2009-10-09  2010-01-06   56.68   24.67      63   True
# ...
